# %%
import matplotlib.pyplot as plt
import pandas as pd
#from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression as LR
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import r2_score
import numpy as np
import seaborn as sb
import scipy

# %%
# importing database
data = pd.read_csv('all_states_merged_8to18.csv')

# %% [markdown]
# # Data Exploration

# %%
data
# Out:
#       Indicator  Total number of pregnant women Registered for ANC  \
# 0             1                                             2253.0
# 1             2                                              925.0
# 2             1                                             1511.0
# 3             2                                             1043.0
# 4             1                                             1279.0
# ...         ...                                                ...
# 6600         12                                            78766.0
# 6601         13                                           146754.0
# 6602         14                                            58172.0
# 6603         15                                           154018.0
# 6604         16                                            72059.0
#
#       Number of Pregnant women registered within first trimester  \
# 0                                                 739.0
# 1                                                 247.0
# 2                                                 611.0
# 3                                                 278.0
# 4                                                 896.0
# ...                                                 ...
# 6600                                            71127.0
# 6601                                           108454.0
# 6602                                            53672.0
# 6603                                           134006.0
# 6604                                            63896.0
#
#       Number of pregnant women received 3 ANC check ups  \
# 0                                                2007.0
# 1                                                 638.0
# 2                                                1491.0
# 3                                                 554.0
# 4                                                1255.0
# ...                                                 ...
# 6600                                             4417.0
# 6601                                             5773.0
# 6602                                            12079.0
# 6603                                            10871.0
# 6604                                            15796.0
#
#       TT2 or Booster given to Pregnant women (numbers)  \
# 0                                               1667.0
# 1                                                584.0
# 2                                               1097.0
# 3                                                485.0
# 4                                               1115.0
# ...                                                ...
# 6600                                              78.1
# 6601                                              66.4
# 6602                                              86.3
# 6603                                              78.3
# 6604                                              84.3
#
#       Number of Pregnant women given 100 IFA tablets  \
# 0                                             7857.0
# 1                                             1230.0
# 2                                             2674.0
# 3                                             1413.0
# 4                                             1397.0
# ...                                              ...
# 6600                                           105.6
# 6601                                            77.6
# 6602                                            86.3
# 6603                                            97.5
# 6604                                            87.5
#
#       Number having Hb level<11 (tested cases)  \
# 0                                       3496.0
# 1                                       4459.0
# 2                                       2715.0
# 3                                       3926.0
# 4                                       1509.0
# ...                                        ...
# 6600                                     214.0
# 6601                                     527.0
# 6602                                     386.0
# 6603                                     416.0
# 6604                                     113.0
#
#       Number having severe anaemia (Hb<7) treated at institution  \
# 0                                                  34.0
# 1                                                 214.0
# 2                                                 192.0
# 3                                                 335.0
# 4                                                  36.0
# ...                                                 ...
# 6600                                               45.6
# 6601                                               65.0
# 6602                                              138.4
# 6603                                               63.0
# 6604                                               58.5
#
#       Number of Home deliveries  \
# 0                         350.0
# 1                          39.0
# 2                         216.0
# 3                          62.0
# 4                         190.0
# ...                         ...
# 6600                        0.0
# 6601                        0.0
# 6602                        0.0
# 6603                        0.0
# 6604                        0.0
#
#       Number of home deliveries attended by SBA trained (Doctor/Nurse/ANM)  \
# 0                                                 123.0
# 1                                                  29.0
# 2                                                  89.0
# 3                                                  52.0
# 4                                                  76.0
# ...                                                 ...
# 6600                                              453.0
# 6601                                             1291.0
# 6602                                             2253.0
# 6603                                             7324.0
# 6604                                            12124.0
#
#       ...  Adverse Events Following Imunisation (Others)  \
# 0     ...                                            0.0
# 1     ...                                            5.0
# 2     ...                                           11.0
# 3     ...                                           46.0
# 4     ...                                           45.0
# ...   ...                                            ...
# 6600  ...                                            0.0
# 6601  ...                                            0.0
# 6602  ...                                            0.0
# 6603  ...                                            0.0
# 6604  ...                                            0.0
#
#       Number of Major Operations  Number of Minor Operations  \
# 0                           29.0                        54.0
# 1                          106.0                       220.0
# 2                            0.0                        17.0
# 3                          116.0                       191.0
# 4                            0.0                        40.0
# ...                          ...                         ...
# 6600                     70804.0                         4.7
# 6601                    124301.0                       -24.8
# 6602                     51416.0                        -5.7
# 6603                    139683.0                       -12.8
# 6604                     65947.0                        -5.7
#
#       Total Number of Infant Deaths reported  Population Persons  \
# 0                                       22.0                   0
# 1                                       24.0               37333
# 2                                       15.0                   0
# 3                                       11.0               36842
# 4                                       15.0                   0
# ...                                      ...                 ...
# 6600                                    32.0             5537761
# 6601                                    34.0            10716264
# 6602                                     1.0             3195015
# 6603                                    54.0             9022134
# 6604                                     7.0             3407367
#
#       Literate Persons  Main workers Persons  Marginal workers Persons  \
# 0                    0                     0                         0
# 1                25449                  9936                      7392
# 2                    0                     0                         0
# 3                25331                  9650                      7473
# 4                    0                     0                         0
# ...                ...                   ...                       ...
# 6600           4104264               1722107                    271793
# 6601           8643832               3348476                    635320
# 6602           1966489                594904                    751587
# 6603           6652454               2228598                   1321785
# 6604           1984664                896702                    272865
#
#       Non-workers Persons  Total Number of reported live births
# 0                       0                                1627.0
# 1                   19974                                 585.0
# 2                       0                                1095.0
# 3                   19717                                 484.0
# 4                       0                                 927.0
# ...                   ...                                   ...
# 6600              3544369                                 927.0
# 6601              6752709                                1046.0
# 6602              1867835                                 963.0
# 6603              5546456                                1422.0
# 6604              2242294                                1311.0
#
# [6605 rows x 47 columns]

# %% [markdown]
# Data has 47 attributes. There are 6605 data examples

# %% [markdown]
# ## 1. Univariate Analysis

# %%
types = pd.DataFrame(data.dtypes)
types = types.T
types
# Out:
#   Indicator Total number of pregnant women Registered for ANC  \
# 0     int64                                           float64
#
#   Number of Pregnant women registered within first trimester  \
# 0                                            float64
#
#   Number of pregnant women received 3 ANC check ups  \
# 0                                           float64
#
#   TT2 or Booster given to Pregnant women (numbers)  \
# 0                                          float64
#
#   Number of Pregnant women given 100 IFA tablets  \
# 0                                        float64
#
#   Number having Hb level<11 (tested cases)  \
# 0                                  float64
#
#   Number having severe anaemia (Hb<7) treated at institution  \
# 0                                            float64
#
#   Number of Home deliveries  \
# 0                   float64
#
#   Number of home deliveries attended by SBA trained (Doctor/Nurse/ANM)  ...  \
# 0                                            float64                    ...
#
#   Adverse Events Following Imunisation (Others) Number of Major Operations  \
# 0                                       float64                    float64
#
#   Number of Minor Operations Total Number of Infant Deaths reported  \
# 0                    float64                                float64
#
#   Population Persons Literate Persons Main workers Persons  \
# 0              int64            int64                int64
#
#   Marginal workers Persons Non-workers Persons  \
# 0                    int64               int64
#
#   Total Number of reported live births
# 0                              float64
#
# [1 rows x 47 columns]

# %%
data.dtypes.value_counts()
# Out:
# float64    41
# int64       6
# dtype: int64

# %% [markdown]
# So there are 41 float type and 6 integer type attributes. All attributes are discrete variables. So our prediction problem in Regression.

# %% [markdown]
# ### 1.1 Identification of Target Attributes

# %% [markdown]
# We have two target attributes for two different prediction test cases.
# - Prediction of number of births in the country:
#     - Target attribute: 'Total Number of reported live births'
# - Prediction of number of still-births in the country:
#     - Target attribute: 'Total Number of reported Still Births'
# - Prediction of number of infant-deaths in the country:
#     - Target attribute: 'Total Number of reported Infant Deaths'

# %%
data.drop("Indicator",axis = 1, inplace = True)
data
# Out:
#       Total number of pregnant women Registered for ANC  \
# 0                                                2253.0
# 1                                                 925.0
# 2                                                1511.0
# 3                                                1043.0
# 4                                                1279.0
# ...                                                 ...
# 6600                                            78766.0
# 6601                                           146754.0
# 6602                                            58172.0
# 6603                                           154018.0
# 6604                                            72059.0
#
#       Number of Pregnant women registered within first trimester  \
# 0                                                 739.0
# 1                                                 247.0
# 2                                                 611.0
# 3                                                 278.0
# 4                                                 896.0
# ...                                                 ...
# 6600                                            71127.0
# 6601                                           108454.0
# 6602                                            53672.0
# 6603                                           134006.0
# 6604                                            63896.0
#
#       Number of pregnant women received 3 ANC check ups  \
# 0                                                2007.0
# 1                                                 638.0
# 2                                                1491.0
# 3                                                 554.0
# 4                                                1255.0
# ...                                                 ...
# 6600                                             4417.0
# 6601                                             5773.0
# 6602                                            12079.0
# 6603                                            10871.0
# 6604                                            15796.0
#
#       TT2 or Booster given to Pregnant women (numbers)  \
# 0                                               1667.0
# 1                                                584.0
# 2                                               1097.0
# 3                                                485.0
# 4                                               1115.0
# ...                                                ...
# 6600                                              78.1
# 6601                                              66.4
# 6602                                              86.3
# 6603                                              78.3
# 6604                                              84.3
#
#       Number of Pregnant women given 100 IFA tablets  \
# 0                                             7857.0
# 1                                             1230.0
# 2                                             2674.0
# 3                                             1413.0
# 4                                             1397.0
# ...                                              ...
# 6600                                           105.6
# 6601                                            77.6
# 6602                                            86.3
# 6603                                            97.5
# 6604                                            87.5
#
#       Number having Hb level<11 (tested cases)  \
# 0                                       3496.0
# 1                                       4459.0
# 2                                       2715.0
# 3                                       3926.0
# 4                                       1509.0
# ...                                        ...
# 6600                                     214.0
# 6601                                     527.0
# 6602                                     386.0
# 6603                                     416.0
# 6604                                     113.0
#
#       Number having severe anaemia (Hb<7) treated at institution  \
# 0                                                  34.0
# 1                                                 214.0
# 2                                                 192.0
# 3                                                 335.0
# 4                                                  36.0
# ...                                                 ...
# 6600                                               45.6
# 6601                                               65.0
# 6602                                              138.4
# 6603                                               63.0
# 6604                                               58.5
#
#       Number of Home deliveries  \
# 0                         350.0
# 1                          39.0
# 2                         216.0
# 3                          62.0
# 4                         190.0
# ...                         ...
# 6600                        0.0
# 6601                        0.0
# 6602                        0.0
# 6603                        0.0
# 6604                        0.0
#
#       Number of home deliveries attended by SBA trained (Doctor/Nurse/ANM)  \
# 0                                                 123.0
# 1                                                  29.0
# 2                                                  89.0
# 3                                                  52.0
# 4                                                  76.0
# ...                                                 ...
# 6600                                              453.0
# 6601                                             1291.0
# 6602                                             2253.0
# 6603                                             7324.0
# 6604                                            12124.0
#
#       Number of home deliveries attended by Non SBA trained (trained TB/Dai)  \
# 0                                                 227.0
# 1                                                  10.0
# 2                                                 127.0
# 3                                                  10.0
# 4                                                 114.0
# ...                                                 ...
# 6600                                                0.0
# 6601                                                0.0
# 6602                                                0.0
# 6603                                                0.0
# 6604                                                0.0
#
#       ...  Adverse Events Following Imunisation (Others)  \
# 0     ...                                            0.0
# 1     ...                                            5.0
# 2     ...                                           11.0
# 3     ...                                           46.0
# 4     ...                                           45.0
# ...   ...                                            ...
# 6600  ...                                            0.0
# 6601  ...                                            0.0
# 6602  ...                                            0.0
# 6603  ...                                            0.0
# 6604  ...                                            0.0
#
#       Number of Major Operations  Number of Minor Operations  \
# 0                           29.0                        54.0
# 1                          106.0                       220.0
# 2                            0.0                        17.0
# 3                          116.0                       191.0
# 4                            0.0                        40.0
# ...                          ...                         ...
# 6600                     70804.0                         4.7
# 6601                    124301.0                       -24.8
# 6602                     51416.0                        -5.7
# 6603                    139683.0                       -12.8
# 6604                     65947.0                        -5.7
#
#       Total Number of Infant Deaths reported  Population Persons  \
# 0                                       22.0                   0
# 1                                       24.0               37333
# 2                                       15.0                   0
# 3                                       11.0               36842
# 4                                       15.0                   0
# ...                                      ...                 ...
# 6600                                    32.0             5537761
# 6601                                    34.0            10716264
# 6602                                     1.0             3195015
# 6603                                    54.0             9022134
# 6604                                     7.0             3407367
#
#       Literate Persons  Main workers Persons  Marginal workers Persons  \
# 0                    0                     0                         0
# 1                25449                  9936                      7392
# 2                    0                     0                         0
# 3                25331                  9650                      7473
# 4                    0                     0                         0
# ...                ...                   ...                       ...
# 6600           4104264               1722107                    271793
# 6601           8643832               3348476                    635320
# 6602           1966489                594904                    751587
# 6603           6652454               2228598                   1321785
# 6604           1984664                896702                    272865
#
#       Non-workers Persons  Total Number of reported live births
# 0                       0                                1627.0
# 1                   19974                                 585.0
# 2                       0                                1095.0
# 3                   19717                                 484.0
# 4                       0                                 927.0
# ...                   ...                                   ...
# 6600              3544369                                 927.0
# 6601              6752709                                1046.0
# 6602              1867835                                 963.0
# 6603              5546456                                1422.0
# 6604              2242294                                1311.0
#
# [6605 rows x 46 columns]

# %%
sb.pairplot(data, vars = ["Total number of pregnant women Registered for ANC","Number of Pregnant women registered within first trimester","Number of pregnant women received 3 ANC check ups"])
plt.show()

# %% [markdown]
# ## 2. Multivariate Analysis

# %% [markdown]
# ### 2.1 Counts, Mean, Standard Deviation, Minimun and Maximum values

# %%
data.describe()
# Out:
#        Total number of pregnant women Registered for ANC  \
# count                                        6605.000000
# mean                                        47790.161544
# std                                         38040.702008
# min                                             0.000000
# 25%                                         21046.000000
# 50%                                         39148.000000
# 75%                                         65140.000000
# max                                        574706.000000
#
#        Number of Pregnant women registered within first trimester  \
# count                                        6605.000000
# mean                                        27123.208024
# std                                         22735.302152
# min                                             0.000000
# 25%                                         10881.000000
# 50%                                         22117.000000
# 75%                                         37403.000000
# max                                        162601.000000
#
#        Number of pregnant women received 3 ANC check ups  \
# count                                        6605.000000
# mean                                        33935.052839
# std                                         26914.712471
# min                                             0.000000
# 25%                                         14971.000000
# 50%                                         28291.000000
# 75%                                         47119.000000
# max                                        241525.000000
#
#        TT2 or Booster given to Pregnant women (numbers)  \
# count                                       6605.000000
# mean                                       36925.564421
# std                                        33016.240832
# min                                            0.000000
# 25%                                        12370.000000
# 50%                                        29649.000000
# 75%                                        52517.000000
# max                                       285098.000000
#
#        Number of Pregnant women given 100 IFA tablets  \
# count                                    6.605000e+03
# mean                                     3.536649e+04
# std                                      4.344406e+04
# min                                      0.000000e+00
# 25%                                      1.268000e+04
# 50%                                      2.661400e+04
# 75%                                      4.621400e+04
# max                                      1.027561e+06
#
#        Number having Hb level<11 (tested cases)  \
# count                               6605.000000
# mean                               15852.476760
# std                                19830.388268
# min                                    0.000000
# 25%                                 1872.000000
# 50%                                 9409.000000
# 75%                                22692.000000
# max                               170012.000000
#
#        Number having severe anaemia (Hb<7) treated at institution  \
# count                                        6605.000000
# mean                                          784.443179
# std                                          1621.633288
# min                                             0.000000
# 25%                                            47.000000
# 50%                                           293.000000
# 75%                                           907.000000
# max                                         31936.000000
#
#        Number of Home deliveries  \
# count                6605.000000
# mean                 6245.941862
# std                 10301.588251
# min                     0.000000
# 25%                   304.000000
# 50%                  2052.000000
# 75%                  7460.000000
# max                 90249.000000
#
#        Number of home deliveries attended by SBA trained (Doctor/Nurse/ANM)  \
# count                                        6605.000000
# mean                                         2802.033611
# std                                          6299.821110
# min                                             0.000000
# 25%                                            52.000000
# 50%                                           468.000000
# 75%                                          2402.000000
# max                                         66591.000000
#
#        Number of home deliveries attended by Non SBA trained (trained TB/Dai)  \
# count                                        6605.000000
# mean                                         3575.753475
# std                                          6033.588073
# min                                             0.000000
# 25%                                           103.000000
# 50%                                          1139.000000
# 75%                                          4422.000000
# max                                         75153.000000
#
#        ...  Adverse Events Following Imunisation (Others)  \
# count  ...                                    6605.000000
# mean   ...                                     273.189553
# std    ...                                    1171.796692
# min    ...                                       0.000000
# 25%    ...                                       0.000000
# 50%    ...                                       3.000000
# 75%    ...                                      79.000000
# max    ...                                   35964.000000
#
#        Number of Major Operations  Number of Minor Operations  \
# count                 6605.000000                 6605.000000
# mean                  7100.287509                 9706.388372
# std                  15885.596969                18745.649531
# min                      0.000000                 -110.900000
# 25%                    502.000000                  750.000000
# 50%                   2316.000000                 3446.000000
# 75%                   6599.000000                 9434.000000
# max                 273417.000000               259105.000000
#
#        Total Number of Infant Deaths reported  Population Persons  \
# count                             6605.000000        6.605000e+03
# mean                               237.532778        2.048917e+06
# std                                392.766730        1.562721e+06
# min                                  0.000000        0.000000e+00
# 25%                                  7.000000        9.949210e+05
# 50%                                 87.000000        1.765333e+06
# 75%                                318.000000        2.835777e+06
# max                               6479.000000        1.371706e+07
#
#        Literate Persons  Main workers Persons  Marginal workers Persons  \
# count      6.605000e+03          6.605000e+03              6.605000e+03
# mean       1.315803e+06          5.896293e+05              2.111897e+05
# std        1.085611e+06          5.144986e+05              1.727393e+05
# min        0.000000e+00          0.000000e+00              0.000000e+00
# 25%        5.986680e+05          2.665790e+05              8.541100e+04
# 50%        1.106693e+06          4.822730e+05              1.680940e+05
# 75%        1.803659e+06          7.790320e+05              2.999220e+05
# max        1.072151e+07          5.413896e+06              1.321785e+06
#
#        Non-workers Persons  Total Number of reported live births
# count         6.605000e+03                           6605.000000
# mean          1.252093e+06                          33320.616200
# std           9.885663e+05                          27065.799978
# min           0.000000e+00                              0.000000
# 25%           5.739830e+05                          14050.000000
# 50%           1.055191e+06                          27804.000000
# 75%           1.738448e+06                          46036.000000
# max           8.002550e+06                         214531.000000
#
# [8 rows x 46 columns]

# %% [markdown]
# ### 2.2 Median

# %%
median = pd.DataFrame(data.median()).T
median
# Out:
#    Total number of pregnant women Registered for ANC  \
# 0                                            39148.0
#
#    Number of Pregnant women registered within first trimester  \
# 0                                            22117.0
#
#    Number of pregnant women received 3 ANC check ups  \
# 0                                            28291.0
#
#    TT2 or Booster given to Pregnant women (numbers)  \
# 0                                           29649.0
#
#    Number of Pregnant women given 100 IFA tablets  \
# 0                                         26614.0
#
#    Number having Hb level<11 (tested cases)  \
# 0                                    9409.0
#
#    Number having severe anaemia (Hb<7) treated at institution  \
# 0                                              293.0
#
#    Number of Home deliveries  \
# 0                     2052.0
#
#    Number of home deliveries attended by SBA trained (Doctor/Nurse/ANM)  \
# 0                                              468.0
#
#    Number of home deliveries attended by Non SBA trained (trained TB/Dai)  \
# 0                                             1139.0
#
#    ...  Adverse Events Following Imunisation (Others)  \
# 0  ...                                            3.0
#
#    Number of Major Operations  Number of Minor Operations  \
# 0                      2316.0                      3446.0
#
#    Total Number of Infant Deaths reported  Population Persons  \
# 0                                    87.0           1765333.0
#
#    Literate Persons  Main workers Persons  Marginal workers Persons  \
# 0         1106693.0              482273.0                  168094.0
#
#    Non-workers Persons  Total Number of reported live births
# 0            1055191.0                               27804.0
#
# [1 rows x 46 columns]

# %% [markdown]
# ### 2.3 Correlation among attributes

# %%
# Correlation Matrix 
data.corr()
# Out:
#                                                     Total number of pregnant women Registered for ANC  \
# Total number of pregnant women Registered for ANC                                            1.000000
# Number of Pregnant women registered within firs...                                           0.823604
# Number of pregnant women received 3 ANC check ups                                            0.881471
# TT2 or Booster given to Pregnant women (numbers)                                             0.813089
# Number of Pregnant women given 100 IFA tablets                                               0.603211
# Number having Hb level<11 (tested cases)                                                     0.405826
# Number having severe anaemia (Hb<7) treated at ...                                           0.313252
# Number of Home deliveries                                                                    0.477660
# Number of home deliveries attended by SBA train...                                           0.401689
# Number of home deliveries attended by Non SBA t...                                           0.420939
# Deliveries Conducted at Public Institutions                                                  0.771384
# Number of Women Discharged under 48 hours of de...                                           0.547261
# Institutional deliveries (Public Insts.+Pvt. In...                                           0.816502
# Total reported deliveries                                                                    0.880790
# Number of C-section deliveries conducted at pub...                                           0.403213
# Number of C-section deliveries conducted at pri...                                           0.283900
# Total Number of reported Still Births                                                        0.193645
# Number of Newborns having weight less than 2.5 kg                                            0.492939
# Number of New Borns Breast Fed within 1 hour                                                 0.699821
# Sex Ratio at birth ( Female Live Bitrths/ Male ...                                          -0.115485
# Total Number of Abortions ( Spontaneous/ Induce...                                           0.301505
# Total Number of MTPs ( Public) reported                                                      0.307985
# Number of Vasectomies Conducted (Public + Pvt.)                                              0.216589
# Number of Tubectomies Conducted (Public + Pvt.)                                              0.553208
# Total Sterilisation Conducted                                                                0.555786
# IUCD Insertions done (public facilities)                                                     0.574245
# IUCD insertions done (pvt. facilities)                                                       0.318568
# Oral Pills distributed                                                                       0.409240
# Condom pieces distributed                                                                    0.405800
# Number of Infants given OPV 0 (Birth Dose)                                                   0.762278
# Number of Infants given BCG                                                                  0.852246
# Number of Infants given DPT1                                                                 0.642773
# Number of Infants given DPT2                                                                 0.648113
# Number of Infants given DPT3                                                                 0.654113
# Number of Infants given Measles                                                              0.830330
# Number of fully immunized children (9-11 months)                                             0.802277
# Adverse Events Following Imunisation (Others)                                                0.071424
# Number of Major Operations                                                                   0.349809
# Number of Minor Operations                                                                   0.209382
# Total Number of Infant Deaths reported                                                       0.257371
# Population Persons                                                                           0.818226
# Literate Persons                                                                             0.761375
# Main workers Persons                                                                         0.687846
# Marginal workers Persons                                                                     0.608507
# Non-workers Persons                                                                          0.831647
# Total Number of reported live births                                                         0.831056
#
#                                                     Number of Pregnant women registered within first trimester  \
# Total number of pregnant women Registered for ANC                                            0.823604
# Number of Pregnant women registered within firs...                                           1.000000
# Number of pregnant women received 3 ANC check ups                                            0.837195
# TT2 or Booster given to Pregnant women (numbers)                                             0.695710
# Number of Pregnant women given 100 IFA tablets                                               0.536822
# Number having Hb level<11 (tested cases)                                                     0.522405
# Number having severe anaemia (Hb<7) treated at ...                                           0.341692
# Number of Home deliveries                                                                    0.364901
# Number of home deliveries attended by SBA train...                                           0.298876
# Number of home deliveries attended by Non SBA t...                                           0.327334
# Deliveries Conducted at Public Institutions                                                  0.693845
# Number of Women Discharged under 48 hours of de...                                           0.487896
# Institutional deliveries (Public Insts.+Pvt. In...                                           0.798924
# Total reported deliveries                                                                    0.819664
# Number of C-section deliveries conducted at pub...                                           0.425133
# Number of C-section deliveries conducted at pri...                                           0.394886
# Total Number of reported Still Births                                                        0.169577
# Number of Newborns having weight less than 2.5 kg                                            0.450668
# Number of New Borns Breast Fed within 1 hour                                                 0.713673
# Sex Ratio at birth ( Female Live Bitrths/ Male ...                                          -0.078765
# Total Number of Abortions ( Spontaneous/ Induce...                                           0.296889
# Total Number of MTPs ( Public) reported                                                      0.241249
# Number of Vasectomies Conducted (Public + Pvt.)                                              0.154628
# Number of Tubectomies Conducted (Public + Pvt.)                                              0.587049
# Total Sterilisation Conducted                                                                0.584623
# IUCD Insertions done (public facilities)                                                     0.536530
# IUCD insertions done (pvt. facilities)                                                       0.312569
# Oral Pills distributed                                                                       0.406970
# Condom pieces distributed                                                                    0.344375
# Number of Infants given OPV 0 (Birth Dose)                                                   0.759827
# Number of Infants given BCG                                                                  0.729530
# Number of Infants given DPT1                                                                 0.470847
# Number of Infants given DPT2                                                                 0.479511
# Number of Infants given DPT3                                                                 0.486624
# Number of Infants given Measles                                                              0.713066
# Number of fully immunized children (9-11 months)                                             0.737576
# Adverse Events Following Imunisation (Others)                                                0.108773
# Number of Major Operations                                                                   0.302637
# Number of Minor Operations                                                                   0.244763
# Total Number of Infant Deaths reported                                                       0.271354
# Population Persons                                                                           0.796617
# Literate Persons                                                                             0.766003
# Main workers Persons                                                                         0.729151
# Marginal workers Persons                                                                     0.547653
# Non-workers Persons                                                                          0.786860
# Total Number of reported live births                                                         0.774981
#
#                                                     Number of pregnant women received 3 ANC check ups  \
# Total number of pregnant women Registered for ANC                                            0.881471
# Number of Pregnant women registered within firs...                                           0.837195
# Number of pregnant women received 3 ANC check ups                                            1.000000
# TT2 or Booster given to Pregnant women (numbers)                                             0.832812
# Number of Pregnant women given 100 IFA tablets                                               0.621550
# Number having Hb level<11 (tested cases)                                                     0.534046
# Number having severe anaemia (Hb<7) treated at ...                                           0.353952
# Number of Home deliveries                                                                    0.466557
# Number of home deliveries attended by SBA train...                                           0.362888
# Number of home deliveries attended by Non SBA t...                                           0.404394
# Deliveries Conducted at Public Institutions                                                  0.789439
# Number of Women Discharged under 48 hours of de...                                           0.549338
# Institutional deliveries (Public Insts.+Pvt. In...                                           0.795485
# Total reported deliveries                                                                    0.848227
# Number of C-section deliveries conducted at pub...                                           0.419034
# Number of C-section deliveries conducted at pri...                                           0.360896
# Total Number of reported Still Births                                                       -0.075663
# Number of Newborns having weight less than 2.5 kg                                            0.295837
# Number of New Borns Breast Fed within 1 hour                                                 0.795310
# Sex Ratio at birth ( Female Live Bitrths/ Male ...                                           0.116240
# Total Number of Abortions ( Spontaneous/ Induce...                                           0.335948
# Total Number of MTPs ( Public) reported                                                      0.095814
# Number of Vasectomies Conducted (Public + Pvt.)                                              0.148145
# Number of Tubectomies Conducted (Public + Pvt.)                                              0.646138
# Total Sterilisation Conducted                                                                0.646877
# IUCD Insertions done (public facilities)                                                     0.633100
# IUCD insertions done (pvt. facilities)                                                       0.343315
# Oral Pills distributed                                                                       0.478083
# Condom pieces distributed                                                                    0.442279
# Number of Infants given OPV 0 (Birth Dose)                                                   0.840690
# Number of Infants given BCG                                                                  0.859092
# Number of Infants given DPT1                                                                 0.601145
# Number of Infants given DPT2                                                                 0.611484
# Number of Infants given DPT3                                                                 0.618789
# Number of Infants given Measles                                                              0.835972
# Number of fully immunized children (9-11 months)                                             0.833326
# Adverse Events Following Imunisation (Others)                                                0.107206
# Number of Major Operations                                                                   0.170860
# Number of Minor Operations                                                                   0.263883
# Total Number of Infant Deaths reported                                                       0.304575
# Population Persons                                                                           0.799979
# Literate Persons                                                                             0.760414
# Main workers Persons                                                                         0.733104
# Marginal workers Persons                                                                     0.541128
# Non-workers Persons                                                                          0.790330
# Total Number of reported live births                                                         0.898800
#
#                                                     TT2 or Booster given to Pregnant women (numbers)  \
# Total number of pregnant women Registered for ANC                                           0.813089
# Number of Pregnant women registered within firs...                                          0.695710
# Number of pregnant women received 3 ANC check ups                                           0.832812
# TT2 or Booster given to Pregnant women (numbers)                                            1.000000
# Number of Pregnant women given 100 IFA tablets                                              0.561036
# Number having Hb level<11 (tested cases)                                                    0.326637
# Number having severe anaemia (Hb<7) treated at ...                                          0.272474
# Number of Home deliveries                                                                   0.588418
# Number of home deliveries attended by SBA train...                                          0.455118
# Number of home deliveries attended by Non SBA t...                                          0.505038
# Deliveries Conducted at Public Institutions                                                 0.756751
# Number of Women Discharged under 48 hours of de...                                          0.575235
# Institutional deliveries (Public Insts.+Pvt. In...                                          0.679467
# Total reported deliveries                                                                   0.794856
# Number of C-section deliveries conducted at pub...                                          0.224500
# Number of C-section deliveries conducted at pri...                                          0.188494
# Total Number of reported Still Births                                                      -0.148859
# Number of Newborns having weight less than 2.5 kg                                           0.255437
# Number of New Borns Breast Fed within 1 hour                                                0.695797
# Sex Ratio at birth ( Female Live Bitrths/ Male ...                                          0.147563
# Total Number of Abortions ( Spontaneous/ Induce...                                          0.259295
# Total Number of MTPs ( Public) reported                                                     0.063322
# Number of Vasectomies Conducted (Public + Pvt.)                                             0.154300
# Number of Tubectomies Conducted (Public + Pvt.)                                             0.575626
# Total Sterilisation Conducted                                                               0.579058
# IUCD Insertions done (public facilities)                                                    0.683033
# IUCD insertions done (pvt. facilities)                                                      0.260691
# Oral Pills distributed                                                                      0.451259
# Condom pieces distributed                                                                   0.438466
# Number of Infants given OPV 0 (Birth Dose)                                                  0.748796
# Number of Infants given BCG                                                                 0.933378
# Number of Infants given DPT1                                                                0.802459
# Number of Infants given DPT2                                                                0.810019
# Number of Infants given DPT3                                                                0.820100
# Number of Infants given Measles                                                             0.942959
# Number of fully immunized children (9-11 months)                                            0.832906
# Adverse Events Following Imunisation (Others)                                               0.063232
# Number of Major Operations                                                                  0.036689
# Number of Minor Operations                                                                  0.109480
# Total Number of Infant Deaths reported                                                      0.208284
# Population Persons                                                                          0.716549
# Literate Persons                                                                            0.627622
# Main workers Persons                                                                        0.592118
# Marginal workers Persons                                                                    0.535476
# Non-workers Persons                                                                         0.731165
# Total Number of reported live births                                                        0.853993
#
#                                                     Number of Pregnant women given 100 IFA tablets  \
# Total number of pregnant women Registered for ANC                                         0.603211
# Number of Pregnant women registered within firs...                                        0.536822
# Number of pregnant women received 3 ANC check ups                                         0.621550
# TT2 or Booster given to Pregnant women (numbers)                                          0.561036
# Number of Pregnant women given 100 IFA tablets                                            1.000000
# Number having Hb level<11 (tested cases)                                                  0.349084
# Number having severe anaemia (Hb<7) treated at ...                                        0.228408
# Number of Home deliveries                                                                 0.284949
# Number of home deliveries attended by SBA train...                                        0.205316
# Number of home deliveries attended by Non SBA t...                                        0.254389
# Deliveries Conducted at Public Institutions                                               0.521113
# Number of Women Discharged under 48 hours of de...                                        0.357863
# Institutional deliveries (Public Insts.+Pvt. In...                                        0.497355
# Total reported deliveries                                                                 0.525084
# Number of C-section deliveries conducted at pub...                                        0.251120
# Number of C-section deliveries conducted at pri...                                        0.204442
# Total Number of reported Still Births                                                    -0.109615
# Number of Newborns having weight less than 2.5 kg                                         0.200249
# Number of New Borns Breast Fed within 1 hour                                              0.507480
# Sex Ratio at birth ( Female Live Bitrths/ Male ...                                        0.117026
# Total Number of Abortions ( Spontaneous/ Induce...                                        0.233550
# Total Number of MTPs ( Public) reported                                                   0.059000
# Number of Vasectomies Conducted (Public + Pvt.)                                           0.097242
# Number of Tubectomies Conducted (Public + Pvt.)                                           0.401020
# Total Sterilisation Conducted                                                             0.402792
# IUCD Insertions done (public facilities)                                                  0.400686
# IUCD insertions done (pvt. facilities)                                                    0.223032
# Oral Pills distributed                                                                    0.325926
# Condom pieces distributed                                                                 0.303845
# Number of Infants given OPV 0 (Birth Dose)                                                0.560028
# Number of Infants given BCG                                                               0.585936
# Number of Infants given DPT1                                                              0.423635
# Number of Infants given DPT2                                                              0.428336
# Number of Infants given DPT3                                                              0.432304
# Number of Infants given Measles                                                           0.566832
# Number of fully immunized children (9-11 months)                                          0.573420
# Adverse Events Following Imunisation (Others)                                             0.056115
# Number of Major Operations                                                                0.046349
# Number of Minor Operations                                                                0.138735
# Total Number of Infant Deaths reported                                                    0.181306
# Population Persons                                                                        0.497486
# Literate Persons                                                                          0.464869
# Main workers Persons                                                                      0.446223
# Marginal workers Persons                                                                  0.341575
# Non-workers Persons                                                                       0.495382
# Total Number of reported live births                                                      0.578746
#
#                                                     Number having Hb level<11 (tested cases)  \
# Total number of pregnant women Registered for ANC                                   0.405826
# Number of Pregnant women registered within firs...                                  0.522405
# Number of pregnant women received 3 ANC check ups                                   0.534046
# TT2 or Booster given to Pregnant women (numbers)                                    0.326637
# Number of Pregnant women given 100 IFA tablets                                      0.349084
# Number having Hb level<11 (tested cases)                                            1.000000
# Number having severe anaemia (Hb<7) treated at ...                                  0.416467
# Number of Home deliveries                                                          -0.072855
# Number of home deliveries attended by SBA train...                                 -0.134285
# Number of home deliveries attended by Non SBA t...                                 -0.000835
# Deliveries Conducted at Public Institutions                                         0.421386
# Number of Women Discharged under 48 hours of de...                                  0.177024
# Institutional deliveries (Public Insts.+Pvt. In...                                  0.537849
# Total reported deliveries                                                           0.420168
# Number of C-section deliveries conducted at pub...                                  0.445417
# Number of C-section deliveries conducted at pri...                                  0.419462
# Total Number of reported Still Births                                              -0.106557
# Number of Newborns having weight less than 2.5 kg                                   0.032614
# Number of New Borns Breast Fed within 1 hour                                        0.527681
# Sex Ratio at birth ( Female Live Bitrths/ Male ...                                  0.137501
# Total Number of Abortions ( Spontaneous/ Induce...                                  0.426659
# Total Number of MTPs ( Public) reported                                             0.025869
# Number of Vasectomies Conducted (Public + Pvt.)                                    -0.019030
# Number of Tubectomies Conducted (Public + Pvt.)                                     0.441714
# Total Sterilisation Conducted                                                       0.434517
# IUCD Insertions done (public facilities)                                            0.313450
# IUCD insertions done (pvt. facilities)                                              0.290938
# Oral Pills distributed                                                              0.322649
# Condom pieces distributed                                                           0.221240
# Number of Infants given OPV 0 (Birth Dose)                                          0.558871
# Number of Infants given BCG                                                         0.381436
# Number of Infants given DPT1                                                        0.007692
# Number of Infants given DPT2                                                        0.022302
# Number of Infants given DPT3                                                        0.033835
# Number of Infants given Measles                                                     0.355202
# Number of fully immunized children (9-11 months)                                    0.387073
# Adverse Events Following Imunisation (Others)                                       0.134739
# Number of Major Operations                                                          0.133418
# Number of Minor Operations                                                          0.379216
# Total Number of Infant Deaths reported                                              0.335851
# Population Persons                                                                  0.466437
# Literate Persons                                                                    0.514489
# Main workers Persons                                                                0.566513
# Marginal workers Persons                                                            0.194828
# Non-workers Persons                                                                 0.410768
# Total Number of reported live births                                                0.455156
#
#                                                     Number having severe anaemia (Hb<7) treated at institution  \
# Total number of pregnant women Registered for ANC                                            0.313252
# Number of Pregnant women registered within firs...                                           0.341692
# Number of pregnant women received 3 ANC check ups                                            0.353952
# TT2 or Booster given to Pregnant women (numbers)                                             0.272474
# Number of Pregnant women given 100 IFA tablets                                               0.228408
# Number having Hb level<11 (tested cases)                                                     0.416467
# Number having severe anaemia (Hb<7) treated at ...                                           1.000000
# Number of Home deliveries                                                                    0.091735
# Number of home deliveries attended by SBA train...                                           0.113042
# Number of home deliveries attended by Non SBA t...                                           0.028439
# Deliveries Conducted at Public Institutions                                                  0.260688
# Number of Women Discharged under 48 hours of de...                                           0.179970
# Institutional deliveries (Public Insts.+Pvt. In...                                           0.307146
# Total reported deliveries                                                                    0.291688
# Number of C-section deliveries conducted at pub...                                           0.191802
# Number of C-section deliveries conducted at pri...                                           0.131041
# Total Number of reported Still Births                                                       -0.062302
# Number of Newborns having weight less than 2.5 kg                                            0.067255
# Number of New Borns Breast Fed within 1 hour                                                 0.316083
# Sex Ratio at birth ( Female Live Bitrths/ Male ...                                           0.067693
# Total Number of Abortions ( Spontaneous/ Induce...                                           0.138756
# Total Number of MTPs ( Public) reported                                                      0.010027
# Number of Vasectomies Conducted (Public + Pvt.)                                              0.020349
# Number of Tubectomies Conducted (Public + Pvt.)                                              0.268651
# Total Sterilisation Conducted                                                                0.266506
# IUCD Insertions done (public facilities)                                                     0.259242
# IUCD insertions done (pvt. facilities)                                                       0.149989
# Oral Pills distributed                                                                       0.136530
# Condom pieces distributed                                                                    0.195845
# Number of Infants given OPV 0 (Birth Dose)                                                   0.316108
# Number of Infants given BCG                                                                  0.275271
# Number of Infants given DPT1                                                                 0.184596
# Number of Infants given DPT2                                                                 0.187437
# Number of Infants given DPT3                                                                 0.191094
# Number of Infants given Measles                                                              0.256062
# Number of fully immunized children (9-11 months)                                             0.279367
# Adverse Events Following Imunisation (Others)                                                0.046519
# Number of Major Operations                                                                   0.047809
# Number of Minor Operations                                                                   0.140342
# Total Number of Infant Deaths reported                                                       0.156891
# Population Persons                                                                           0.256808
# Literate Persons                                                                             0.240665
# Main workers Persons                                                                         0.283124
# Marginal workers Persons                                                                     0.094793
# Non-workers Persons                                                                          0.242012
# Total Number of reported live births                                                         0.306288
#
#                                                     Number of Home deliveries  \
# Total number of pregnant women Registered for ANC                    0.477660
# Number of Pregnant women registered within firs...                   0.364901
# Number of pregnant women received 3 ANC check ups                    0.466557
# TT2 or Booster given to Pregnant women (numbers)                     0.588418
# Number of Pregnant women given 100 IFA tablets                       0.284949
# Number having Hb level<11 (tested cases)                            -0.072855
# Number having severe anaemia (Hb<7) treated at ...                   0.091735
# Number of Home deliveries                                            1.000000
# Number of home deliveries attended by SBA train...                   0.823707
# Number of home deliveries attended by Non SBA t...                   0.836443
# Deliveries Conducted at Public Institutions                          0.420564
# Number of Women Discharged under 48 hours of de...                   0.437340
# Institutional deliveries (Public Insts.+Pvt. In...                   0.197707
# Total reported deliveries                                            0.553244
# Number of C-section deliveries conducted at pub...                  -0.084052
# Number of C-section deliveries conducted at pri...                  -0.133284
# Total Number of reported Still Births                               -0.055468
# Number of Newborns having weight less than 2.5 kg                    0.269444
# Number of New Borns Breast Fed within 1 hour                         0.369193
# Sex Ratio at birth ( Female Live Bitrths/ Male ...                   0.052445
# Total Number of Abortions ( Spontaneous/ Induce...                  -0.057235
# Total Number of MTPs ( Public) reported                             -0.024139
# Number of Vasectomies Conducted (Public + Pvt.)                      0.050609
# Number of Tubectomies Conducted (Public + Pvt.)                      0.108637
# Total Sterilisation Conducted                                        0.111646
# IUCD Insertions done (public facilities)                             0.456799
# IUCD insertions done (pvt. facilities)                              -0.037492
# Oral Pills distributed                                               0.227809
# Condom pieces distributed                                            0.194863
# Number of Infants given OPV 0 (Birth Dose)                           0.285947
# Number of Infants given BCG                                          0.572928
# Number of Infants given DPT1                                         0.609683
# Number of Infants given DPT2                                         0.607608
# Number of Infants given DPT3                                         0.604808
# Number of Infants given Measles                                      0.575584
# Number of fully immunized children (9-11 months)                     0.516501
# Adverse Events Following Imunisation (Others)                       -0.028207
# Number of Major Operations                                          -0.030056
# Number of Minor Operations                                          -0.086135
# Total Number of Infant Deaths reported                              -0.010434
# Population Persons                                                   0.340548
# Literate Persons                                                     0.203109
# Main workers Persons                                                 0.137717
# Marginal workers Persons                                             0.394900
# Non-workers Persons                                                  0.397648
# Total Number of reported live births                                 0.544331
#
#                                                     Number of home deliveries attended by SBA trained (Doctor/Nurse/ANM)  \
# Total number of pregnant women Registered for ANC                                            0.401689
# Number of Pregnant women registered within firs...                                           0.298876
# Number of pregnant women received 3 ANC check ups                                            0.362888
# TT2 or Booster given to Pregnant women (numbers)                                             0.455118
# Number of Pregnant women given 100 IFA tablets                                               0.205316
# Number having Hb level<11 (tested cases)                                                    -0.134285
# Number having severe anaemia (Hb<7) treated at ...                                           0.113042
# Number of Home deliveries                                                                    0.823707
# Number of home deliveries attended by SBA train...                                           1.000000
# Number of home deliveries attended by Non SBA t...                                           0.397650
# Deliveries Conducted at Public Institutions                                                  0.276582
# Number of Women Discharged under 48 hours of de...                                           0.293576
# Institutional deliveries (Public Insts.+Pvt. In...                                           0.151191
# Total reported deliveries                                                                    0.457234
# Number of C-section deliveries conducted at pub...                                          -0.079139
# Number of C-section deliveries conducted at pri...                                          -0.118164
# Total Number of reported Still Births                                                        0.109773
# Number of Newborns having weight less than 2.5 kg                                            0.375066
# Number of New Borns Breast Fed within 1 hour                                                 0.230457
# Sex Ratio at birth ( Female Live Bitrths/ Male ...                                          -0.089415
# Total Number of Abortions ( Spontaneous/ Induce...                                          -0.074811
# Total Number of MTPs ( Public) reported                                                      0.055393
# Number of Vasectomies Conducted (Public + Pvt.)                                              0.032637
# Number of Tubectomies Conducted (Public + Pvt.)                                              0.042998
# Total Sterilisation Conducted                                                                0.043784
# IUCD Insertions done (public facilities)                                                     0.446293
# IUCD insertions done (pvt. facilities)                                                      -0.017944
# Oral Pills distributed                                                                       0.108928
# Condom pieces distributed                                                                    0.151520
# Number of Infants given OPV 0 (Birth Dose)                                                   0.159316
# Number of Infants given BCG                                                                  0.426163
# Number of Infants given DPT1                                                                 0.520129
# Number of Infants given DPT2                                                                 0.511161
# Number of Infants given DPT3                                                                 0.509664
# Number of Infants given Measles                                                              0.435850
# Number of fully immunized children (9-11 months)                                             0.399293
# Adverse Events Following Imunisation (Others)                                               -0.058848
# Number of Major Operations                                                                   0.091307
# Number of Minor Operations                                                                  -0.109696
# Total Number of Infant Deaths reported                                                      -0.124110
# Population Persons                                                                           0.275935
# Literate Persons                                                                             0.170001
# Main workers Persons                                                                         0.112067
# Marginal workers Persons                                                                     0.288043
# Non-workers Persons                                                                          0.326808
# Total Number of reported live births                                                         0.380251
#
#                                                     Number of home deliveries attended by Non SBA trained (trained TB/Dai)  \
# Total number of pregnant women Registered for ANC                                            0.420939
# Number of Pregnant women registered within firs...                                           0.327334
# Number of pregnant women received 3 ANC check ups                                            0.404394
# TT2 or Booster given to Pregnant women (numbers)                                             0.505038
# Number of Pregnant women given 100 IFA tablets                                               0.254389
# Number having Hb level<11 (tested cases)                                                    -0.000835
# Number having severe anaemia (Hb<7) treated at ...                                           0.028439
# Number of Home deliveries                                                                    0.836443
# Number of home deliveries attended by SBA train...                                           0.397650
# Number of home deliveries attended by Non SBA t...                                           1.000000
# Deliveries Conducted at Public Institutions                                                  0.409529
# Number of Women Discharged under 48 hours of de...                                           0.423898
# Institutional deliveries (Public Insts.+Pvt. In...                                           0.197574
# Total reported deliveries                                                                    0.488624
# Number of C-section deliveries conducted at pub...                                          -0.061829
# Number of C-section deliveries conducted at pri...                                          -0.107308
# Total Number of reported Still Births                                                       -0.073336
# Number of Newborns having weight less than 2.5 kg                                            0.173225
# Number of New Borns Breast Fed within 1 hour                                                 0.365717
# Sex Ratio at birth ( Female Live Bitrths/ Male ...                                           0.078633
# Total Number of Abortions ( Spontaneous/ Induce...                                          -0.031173
# Total Number of MTPs ( Public) reported                                                     -0.038510
# Number of Vasectomies Conducted (Public + Pvt.)                                              0.068695
# Number of Tubectomies Conducted (Public + Pvt.)                                              0.120917
# Total Sterilisation Conducted                                                                0.125084
# IUCD Insertions done (public facilities)                                                     0.292245
# IUCD insertions done (pvt. facilities)                                                      -0.050967
# ...
# Number of fully immunized children (9-11 months)            0.672511
# Adverse Events Following Imunisation (Others)               0.148170
# Number of Major Operations                                  0.351253
# Number of Minor Operations                                  0.262837
# Total Number of Infant Deaths reported                      0.269338
# Population Persons                                          0.970213
# Literate Persons                                            1.000000
# Main workers Persons                                        0.932957
# Marginal workers Persons                                    0.593707
# Non-workers Persons                                         0.947194
# Total Number of reported live births                        0.700217
#
#                                                     Main workers Persons  \
# Total number of pregnant women Registered for ANC               0.687846
# Number of Pregnant women registered within firs...              0.729151
# Number of pregnant women received 3 ANC check ups               0.733104
# TT2 or Booster given to Pregnant women (numbers)                0.592118
# Number of Pregnant women given 100 IFA tablets                  0.446223
# Number having Hb level<11 (tested cases)                        0.566513
# Number having severe anaemia (Hb<7) treated at ...              0.283124
# Number of Home deliveries                                       0.137717
# Number of home deliveries attended by SBA train...              0.112067
# Number of home deliveries attended by Non SBA t...              0.127149
# Deliveries Conducted at Public Institutions                     0.549143
# Number of Women Discharged under 48 hours of de...              0.252437
# Institutional deliveries (Public Insts.+Pvt. In...              0.766167
# Total reported deliveries                                       0.701600
# Number of C-section deliveries conducted at pub...              0.485331
# Number of C-section deliveries conducted at pri...              0.530202
# Total Number of reported Still Births                           0.124366
# Number of Newborns having weight less than 2.5 kg               0.327851
# Number of New Borns Breast Fed within 1 hour                    0.583604
# Sex Ratio at birth ( Female Live Bitrths/ Male ...             -0.058897
# Total Number of Abortions ( Spontaneous/ Induce...              0.405007
# Total Number of MTPs ( Public) reported                         0.247438
# Number of Vasectomies Conducted (Public + Pvt.)                 0.214021
# Number of Tubectomies Conducted (Public + Pvt.)                 0.684028
# Total Sterilisation Conducted                                   0.684202
# IUCD Insertions done (public facilities)                        0.420544
# IUCD insertions done (pvt. facilities)                          0.398465
# Oral Pills distributed                                          0.416736
# Condom pieces distributed                                       0.347703
# Number of Infants given OPV 0 (Birth Dose)                      0.734513
# Number of Infants given BCG                                     0.631896
# Number of Infants given DPT1                                    0.387800
# Number of Infants given DPT2                                    0.394986
# Number of Infants given DPT3                                    0.402077
# Number of Infants given Measles                                 0.609758
# Number of fully immunized children (9-11 months)                0.624124
# Adverse Events Following Imunisation (Others)                   0.144987
# Number of Major Operations                                      0.269616
# Number of Minor Operations                                      0.252316
# Total Number of Infant Deaths reported                          0.349493
# Population Persons                                              0.912405
# Literate Persons                                                0.932957
# Main workers Persons                                            1.000000
# Marginal workers Persons                                        0.435466
# Non-workers Persons                                             0.847326
# Total Number of reported live births                            0.671521
#
#                                                     Marginal workers Persons  \
# Total number of pregnant women Registered for ANC                   0.608507
# Number of Pregnant women registered within firs...                  0.547653
# Number of pregnant women received 3 ANC check ups                   0.541128
# TT2 or Booster given to Pregnant women (numbers)                    0.535476
# Number of Pregnant women given 100 IFA tablets                      0.341575
# Number having Hb level<11 (tested cases)                            0.194828
# Number having severe anaemia (Hb<7) treated at ...                  0.094793
# Number of Home deliveries                                           0.394900
# Number of home deliveries attended by SBA train...                  0.288043
# Number of home deliveries attended by Non SBA t...                  0.399194
# Deliveries Conducted at Public Institutions                         0.629569
# Number of Women Discharged under 48 hours of de...                  0.567587
# Institutional deliveries (Public Insts.+Pvt. In...                  0.543471
# Total reported deliveries                                           0.618850
# Number of C-section deliveries conducted at pub...                  0.140367
# Number of C-section deliveries conducted at pri...                  0.069060
# Total Number of reported Still Births                               0.225711
# Number of Newborns having weight less than 2.5 kg                   0.372574
# Number of New Borns Breast Fed within 1 hour                        0.526096
# Sex Ratio at birth ( Female Live Bitrths/ Male ...                 -0.132671
# Total Number of Abortions ( Spontaneous/ Induce...                  0.033894
# Total Number of MTPs ( Public) reported                             0.127180
# Number of Vasectomies Conducted (Public + Pvt.)                     0.129945
# Number of Tubectomies Conducted (Public + Pvt.)                     0.339443
# Total Sterilisation Conducted                                       0.339500
# IUCD Insertions done (public facilities)                            0.336548
# IUCD insertions done (pvt. facilities)                              0.036362
# Oral Pills distributed                                              0.267488
# Condom pieces distributed                                           0.132347
# Number of Infants given OPV 0 (Birth Dose)                          0.450842
# Number of Infants given BCG                                         0.574891
# Number of Infants given DPT1                                        0.392425
# Number of Infants given DPT2                                        0.402430
# Number of Infants given DPT3                                        0.403474
# Number of Infants given Measles                                     0.573569
# Number of fully immunized children (9-11 months)                    0.557842
# Adverse Events Following Imunisation (Others)                       0.093077
# Number of Major Operations                                          0.245716
# Number of Minor Operations                                          0.097186
# Total Number of Infant Deaths reported                              0.116882
# Population Persons                                                  0.694474
# Literate Persons                                                    0.593707
# Main workers Persons                                                0.435466
# Marginal workers Persons                                            1.000000
# Non-workers Persons                                                 0.701407
# Total Number of reported live births                                0.544730
#
#                                                     Non-workers Persons  \
# Total number of pregnant women Registered for ANC              0.831647
# Number of Pregnant women registered within firs...             0.786860
# Number of pregnant women received 3 ANC check ups              0.790330
# TT2 or Booster given to Pregnant women (numbers)               0.731165
# Number of Pregnant women given 100 IFA tablets                 0.495382
# Number having Hb level<11 (tested cases)                       0.410768
# Number having severe anaemia (Hb<7) treated at ...             0.242012
# Number of Home deliveries                                      0.397648
# Number of home deliveries attended by SBA train...             0.326808
# Number of home deliveries attended by Non SBA t...             0.363404
# Deliveries Conducted at Public Institutions                    0.691069
# Number of Women Discharged under 48 hours of de...             0.494574
# Institutional deliveries (Public Insts.+Pvt. In...             0.775363
# Total reported deliveries                                      0.815237
# Number of C-section deliveries conducted at pub...             0.373258
# Number of C-section deliveries conducted at pri...             0.356831
# Total Number of reported Still Births                          0.206388
# Number of Newborns having weight less than 2.5 kg              0.450300
# Number of New Borns Breast Fed within 1 hour                   0.666566
# Sex Ratio at birth ( Female Live Bitrths/ Male ...            -0.128756
# Total Number of Abortions ( Spontaneous/ Induce...             0.267939
# Total Number of MTPs ( Public) reported                        0.242813
# Number of Vasectomies Conducted (Public + Pvt.)                0.184640
# Number of Tubectomies Conducted (Public + Pvt.)                0.542472
# Total Sterilisation Conducted                                  0.542428
# IUCD Insertions done (public facilities)                       0.516321
# IUCD insertions done (pvt. facilities)                         0.288401
# Oral Pills distributed                                         0.371611
# Condom pieces distributed                                      0.301761
# Number of Infants given OPV 0 (Birth Dose)                     0.735748
# Number of Infants given BCG                                    0.783996
# Number of Infants given DPT1                                   0.546725
# Number of Infants given DPT2                                   0.553762
# Number of Infants given DPT3                                   0.558453
# Number of Infants given Measles                                0.767600
# Number of fully immunized children (9-11 months)               0.757437
# Adverse Events Following Imunisation (Others)                  0.114168
# Number of Major Operations                                     0.336415
# Number of Minor Operations                                     0.211040
# Total Number of Infant Deaths reported                         0.192037
# Population Persons                                             0.987323
# Literate Persons                                               0.947194
# Main workers Persons                                           0.847326
# Marginal workers Persons                                       0.701407
# Non-workers Persons                                            1.000000
# Total Number of reported live births                           0.759651
#
#                                                     Total Number of reported live births
# Total number of pregnant women Registered for ANC                               0.831056
# Number of Pregnant women registered within firs...                              0.774981
# Number of pregnant women received 3 ANC check ups                               0.898800
# TT2 or Booster given to Pregnant women (numbers)                                0.853993
# Number of Pregnant women given 100 IFA tablets                                  0.578746
# Number having Hb level<11 (tested cases)                                        0.455156
# Number having severe anaemia (Hb<7) treated at ...                              0.306288
# Number of Home deliveries                                                       0.544331
# Number of home deliveries attended by SBA train...                              0.380251
# Number of home deliveries attended by Non SBA t...                              0.506149
# Deliveries Conducted at Public Institutions                                     0.822986
# Number of Women Discharged under 48 hours of de...                              0.606593
# Institutional deliveries (Public Insts.+Pvt. In...                              0.830570
# Total reported deliveries                                                       0.904494
# Number of C-section deliveries conducted at pub...                              0.356992
# Number of C-section deliveries conducted at pri...                              0.362372
# Total Number of reported Still Births                                          -0.157950
# Number of Newborns having weight less than 2.5 kg                               0.262786
# Number of New Borns Breast Fed within 1 hour                                    0.854164
# Sex Ratio at birth ( Female Live Bitrths/ Male ...                              0.203839
# Total Number of Abortions ( Spontaneous/ Induce...                              0.344393
# Total Number of MTPs ( Public) reported                                         0.056535
# Number of Vasectomies Conducted (Public + Pvt.)                                 0.142482
# Number of Tubectomies Conducted (Public + Pvt.)                                 0.677717
# Total Sterilisation Conducted                                                   0.678742
# IUCD Insertions done (public facilities)                                        0.657919
# IUCD insertions done (pvt. facilities)                                          0.349868
# Oral Pills distributed                                                          0.492196
# Condom pieces distributed                                                       0.473441
# Number of Infants given OPV 0 (Birth Dose)                                      0.875438
# Number of Infants given BCG                                                     0.895237
# Number of Infants given DPT1                                                    0.657786
# Number of Infants given DPT2                                                    0.670095
# Number of Infants given DPT3                                                    0.674658
# Number of Infants given Measles                                                 0.872951
# Number of fully immunized children (9-11 months)                                0.851422
# Adverse Events Following Imunisation (Others)                                   0.107287
# Number of Major Operations                                                      0.084684
# Number of Minor Operations                                                      0.220074
# Total Number of Infant Deaths reported                                          0.358854
# Population Persons                                                              0.760825
# Literate Persons                                                                0.700217
# Main workers Persons                                                            0.671521
# Marginal workers Persons                                                        0.544730
# Non-workers Persons                                                             0.759651
# Total Number of reported live births                                            1.000000
#
# [46 rows x 46 columns]

# %%
# Correlation Heatmap of correlation
column_numbers = np.arange(0,46,1)
data_numbers = data.copy()
data_numbers.columns = column_numbers
fig = plt.figure(figsize = (15,15))
sb.heatmap(data_numbers.corr(),cmap="rocket_r")
plt.title("Heatmap of Collinear Matrix")
plt.xlabel("Attribute Numbers")
plt.ylabel("Attribute Numbers")
plt.savefig('images/heatmap.jpg')
plt.show()
# sb.heatmap(data.corr(),annot= True)

# %% [markdown]
# There are lot of dark squares in above heat map. So it shows that data attributes are highly correlated to each other.
#
# We found that the attribute 'Number of Pregnant women registered within first trimester' is highly correlated to the attributes - 'Deliveries Conducted at Public Institutions', 'Number of pregnant women received 3 ANC check ups', 'TT2 or Booster given to Pregnant women (numbers)'. This shows that women who registered within first trimester with ANC receives 3 ANC check ups, TT2 supplement are very likely to have delivery at some institution- clinic -public or private. Women those have home deliveries don't register themselves with ANC.

# %% [markdown]
# ## 3. Missing Values Treatment

# %%
# Number of zeroes present in the dataset.
k = (data == 0)
k = pd.DataFrame(k.sum().sort_values(ascending = False),columns = ["Number of zeroes present"])
k[k["Number of zeroes present"] >100]
# Out:
#                                                     Number of zeroes present
# IUCD insertions done (pvt. facilities)                                  3018
# Adverse Events Following Imunisation (Others)                           2864
# Number of C-section deliveries conducted at pri...                      2331
# Total Number of Infant Deaths reported                                  1061
# Number of Infants given DPT1                                             739
# Number having severe anaemia (Hb<7) treated at ...                       661
# Number of Vasectomies Conducted (Public + Pvt.)                          627
# Number of Major Operations                                               622
# Number of Infants given DPT2                                             615
# Number of Infants given DPT3                                             577
# Number of Women Discharged under 48 hours of de...                       478
# Number of Minor Operations                                               455
# Number having Hb level<11 (tested cases)                                 449
# Total Number of MTPs ( Public) reported                                  405
# Number of home deliveries attended by SBA train...                       363
# Total Number of Abortions ( Spontaneous/ Induce...                       328
# Number of C-section deliveries conducted at pub...                       327
# Number of New Borns Breast Fed within 1 hour                             284
# Oral Pills distributed                                                   249
# Number of home deliveries attended by Non SBA t...                       239
# Marginal workers Persons                                                 235
# Non-workers Persons                                                      235
# Population Persons                                                       235
# Main workers Persons                                                     235
# Literate Persons                                                         235
# Condom pieces distributed                                                223
# Number of Infants given OPV 0 (Birth Dose)                               149
# Number of Infants given BCG                                              147
# Number of Home deliveries                                                141
# Number of Tubectomies Conducted (Public + Pvt.)                          105

# %% [markdown]
# So there are lot of zeroes present in the data set, but we do not know whether these are missing values or actual value of the data example is zero. So we can't do anything at this stage. To control the effect of the missing values in our result we will make sure to handle the real missing values in outlier analysis below.

# %% [markdown]
# ## 4. Outlier Detection

# %% [markdown]
# #### 4.1 IQR Analysis

# %%
IQR = pd.DataFrame(data.apply(scipy.stats.iqr)).T
IQR
# Out:
#    Total number of pregnant women Registered for ANC  \
# 0                                            44094.0
#
#    Number of Pregnant women registered within first trimester  \
# 0                                            26522.0
#
#    Number of pregnant women received 3 ANC check ups  \
# 0                                            32148.0
#
#    TT2 or Booster given to Pregnant women (numbers)  \
# 0                                           40147.0
#
#    Number of Pregnant women given 100 IFA tablets  \
# 0                                         33534.0
#
#    Number having Hb level<11 (tested cases)  \
# 0                                   20820.0
#
#    Number having severe anaemia (Hb<7) treated at institution  \
# 0                                              860.0
#
#    Number of Home deliveries  \
# 0                     7156.0
#
#    Number of home deliveries attended by SBA trained (Doctor/Nurse/ANM)  \
# 0                                             2350.0
#
#    Number of home deliveries attended by Non SBA trained (trained TB/Dai)  \
# 0                                             4319.0
#
#    ...  Adverse Events Following Imunisation (Others)  \
# 0  ...                                           79.0
#
#    Number of Major Operations  Number of Minor Operations  \
# 0                      6097.0                      8684.0
#
#    Total Number of Infant Deaths reported  Population Persons  \
# 0                                   311.0           1840856.0
#
#    Literate Persons  Main workers Persons  Marginal workers Persons  \
# 0         1204991.0              512453.0                  214511.0
#
#    Non-workers Persons  Total Number of reported live births
# 0            1164465.0                               31986.0
#
# [1 rows x 46 columns]

# %%
# Finding out the number of outliers in each data attribute
Q1 = data.quantile(0.25)
Q3 = data.quantile(0.75)
IQR = Q3 - Q1
df = data.copy()
outliers = (df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))
pd.DataFrame(outliers.sum().sort_values(ascending = False),columns=["Number of Outliers"])
# Out:
#                                                     Number of Outliers
# Adverse Events Following Imunisation (Others)                     1106
# IUCD insertions done (pvt. facilities)                             989
# Number of home deliveries attended by SBA train...                 854
# Number of Minor Operations                                         791
# Number of Vasectomies Conducted (Public + Pvt.)                    783
# Number of C-section deliveries conducted at pri...                 731
# Total Number of MTPs ( Public) reported                            698
# Number of Major Operations                                         669
# Number of Newborns having weight less than 2.5 kg                  662
# Number of Home deliveries                                          661
# Number of home deliveries attended by Non SBA t...                 597
# Number of C-section deliveries conducted at pub...                 551
# Number having severe anaemia (Hb<7) treated at ...                 545
# Condom pieces distributed                                          532
# Oral Pills distributed                                             521
# Sex Ratio at birth ( Female Live Bitrths/ Male ...                 505
# Total Number of Abortions ( Spontaneous/ Induce...                 477
# Total Number of reported Still Births                              470
# Total Number of Infant Deaths reported                             468
# Total Sterilisation Conducted                                      362
# Number of Tubectomies Conducted (Public + Pvt.)                    353
# Number of Women Discharged under 48 hours of de...                 314
# Number having Hb level<11 (tested cases)                           300
# Main workers Persons                                               299
# Number of Pregnant women given 100 IFA tablets                     287
# Number of fully immunized children (9-11 months)                   276
# Number of Infants given Measles                                    263
# Number of Infants given BCG                                        263
# Number of Pregnant women registered within firs...                 259
# IUCD Insertions done (public facilities)                           255
# TT2 or Booster given to Pregnant women (numbers)                   216
# Total number of pregnant women Registered for ANC                  214
# Total Number of reported live births                               204
# Institutional deliveries (Public Insts.+Pvt. In...                 203
# Total reported deliveries                                          202
# Number of pregnant women received 3 ANC check ups                  201
# Number of Infants given OPV 0 (Birth Dose)                         196
# Marginal workers Persons                                           193
# Number of Infants given DPT2                                       190
# Deliveries Conducted at Public Institutions                        189
# Number of Infants given DPT3                                       184
# Number of Infants given DPT1                                       179
# Literate Persons                                                   179
# Number of New Borns Breast Fed within 1 hour                       165
# Non-workers Persons                                                151
# Population Persons                                                 136

# %% [markdown]
# #### 4.2 ZScore Analysis

# %%
# Calculating z-scores
z = data.apply(scipy.stats.zscore)
z
# Out:
#       Total number of pregnant women Registered for ANC  \
# 0                                             -1.197155
# 1                                             -1.232067
# 2                                             -1.216662
# 3                                             -1.228965
# 4                                             -1.222761
# ...                                                 ...
# 6600                                           0.814343
# 6601                                           2.601722
# 6602                                           0.272935
# 6603                                           2.792690
# 6604                                           0.638019
#
#       Number of Pregnant women registered within first trimester  \
# 0                                             -1.160583
# 1                                             -1.182225
# 2                                             -1.166213
# 3                                             -1.180861
# 4                                             -1.153677
# ...                                                 ...
# 6600                                           1.935630
# 6601                                           3.577562
# 6602                                           1.167823
# 6603                                           4.701538
# 6604                                           1.617554
#
#       Number of pregnant women received 3 ANC check ups  \
# 0                                             -1.186357
# 1                                             -1.237226
# 2                                             -1.205531
# 3                                             -1.240347
# 4                                             -1.214300
# ...                                                 ...
# 6600                                          -1.096809
# 6601                                          -1.046423
# 6602                                          -0.812110
# 6603                                          -0.856996
# 6604                                          -0.673997
#
#       TT2 or Booster given to Pregnant women (numbers)  \
# 0                                            -1.067997
# 1                                            -1.100801
# 2                                            -1.085262
# 3                                            -1.103800
# 4                                            -1.084717
# ...                                                ...
# 6600                                         -1.116125
# 6601                                         -1.116479
# 6602                                         -1.115877
# 6603                                         -1.116119
# 6604                                         -1.115937
#
#       Number of Pregnant women given 100 IFA tablets  \
# 0                                          -0.633264
# 1                                          -0.785817
# 2                                          -0.752576
# 3                                          -0.781604
# 4                                          -0.781973
# ...                                              ...
# 6600                                       -0.811700
# 6601                                       -0.812345
# 6602                                       -0.812145
# 6603                                       -0.811887
# 6604                                       -0.812117
#
#       Number having Hb level<11 (tested cases)  \
# 0                                    -0.623155
# 1                                    -0.574590
# 2                                    -0.662542
# 3                                    -0.601470
# 4                                    -0.723363
# ...                                        ...
# 6600                                 -0.788671
# 6601                                 -0.772886
# 6602                                 -0.779997
# 6603                                 -0.778484
# 6604                                 -0.793765
#
#       Number having severe anaemia (Hb<7) treated at institution  \
# 0                                             -0.462805
# 1                                             -0.351797
# 2                                             -0.365365
# 3                                             -0.277176
# 4                                             -0.461572
# ...                                                 ...
# 6600                                          -0.455651
# 6601                                          -0.443687
# 6602                                          -0.398421
# 6603                                          -0.444920
# 6604                                          -0.447696
#
#       Number of Home deliveries  \
# 0                     -0.572377
# 1                     -0.602568
# 2                     -0.585385
# 3                     -0.600336
# 4                     -0.587909
# ...                         ...
# 6600                  -0.606355
# 6601                  -0.606355
# 6602                  -0.606355
# 6603                  -0.606355
# 6604                  -0.606355
#
#       Number of home deliveries attended by SBA trained (Doctor/Nurse/ANM)  \
# 0                                             -0.425288
# 1                                             -0.440210
# 2                                             -0.430685
# 3                                             -0.436559
# 4                                             -0.432749
# ...                                                 ...
# 6600                                          -0.372901
# 6601                                          -0.239872
# 6602                                          -0.087157
# 6603                                           0.717847
# 6604                                           1.479831
#
#       Number of home deliveries attended by Non SBA trained (trained TB/Dai)  \
# 0                                             -0.555061
# 1                                             -0.591029
# 2                                             -0.571636
# 3                                             -0.591029
# 4                                             -0.573791
# ...                                                 ...
# 6600                                          -0.592686
# 6601                                          -0.592686
# 6602                                          -0.592686
# 6603                                          -0.592686
# 6604                                          -0.592686
#
#       ...  Adverse Events Following Imunisation (Others)  \
# 0     ...                                      -0.233155
# 1     ...                                      -0.228888
# 2     ...                                      -0.223767
# 3     ...                                      -0.193896
# 4     ...                                      -0.194750
# ...   ...                                            ...
# 6600  ...                                      -0.233155
# 6601  ...                                      -0.233155
# 6602  ...                                      -0.233155
# 6603  ...                                      -0.233155
# 6604  ...                                      -0.233155
#
#       Number of Major Operations  Number of Minor Operations  \
# 0                      -0.445172                   -0.514953
# 1                      -0.440324                   -0.506096
# 2                      -0.446998                   -0.516926
# 3                      -0.439695                   -0.507644
# 4                      -0.446998                   -0.515699
# ...                          ...                         ...
# 6600                    4.010459                   -0.517583
# 6601                    7.378356                   -0.519156
# 6602                    2.789890                   -0.518137
# 6603                    8.346728                   -0.518516
# 6604                    3.704687                   -0.518137
#
#       Total Number of Infant Deaths reported  Population Persons  \
# 0                                  -0.548797           -1.311220
# 1                                  -0.543704           -1.287329
# 2                                  -0.566620           -1.311220
# 3                                  -0.576805           -1.287643
# 4                                  -0.566620           -1.311220
# ...                                      ...                 ...
# 6600                               -0.523334            2.232713
# 6601                               -0.518242            5.546736
# 6602                               -0.602268            0.733454
# 6603                               -0.467317            4.462565
# 6604                               -0.586990            0.869351
#
#       Literate Persons  Main workers Persons  Marginal workers Persons  \
# 0            -1.212131             -1.146114                 -1.222684
# 1            -1.188687             -1.126800                 -1.179888
# 2            -1.212131             -1.146114                 -1.222684
# 3            -1.188796             -1.127356                 -1.179419
# 4            -1.212131             -1.146114                 -1.222684
# ...                ...                   ...                       ...
# 6600          2.568759              2.201295                  0.350863
# 6601          6.750656              5.362610                  2.455506
# 6602          0.599419              0.010253                  3.128634
# 6603          4.916178              3.185806                  6.429800
# 6604          0.616162              0.596884                  0.357070
#
#       Non-workers Persons  Total Number of reported live births
# 0               -1.266670                             -1.171073
# 1               -1.246464                             -1.209574
# 2               -1.266670                             -1.190730
# 3               -1.246724                             -1.213306
# 4               -1.266670                             -1.196937
# ...                   ...                                   ...
# 6600             2.318964                             -1.196937
# 6601             5.564658                             -1.192540
# 6602             0.622911                             -1.195607
# 6603             4.344361                             -1.178647
# 6604             1.001730                             -1.182749
#
# [6605 rows x 46 columns]

# %%
# Understanding the results
h = []
for i in range(len(z.columns)):
    h.extend(list(z.iloc[:,i]))
    
k = pd.DataFrame(h)
k = k.describe()
k.columns = ["z-score analysis"]
k.round(3).T
# Out:
#                      count  mean  std    min    25%    50%    75%    max
# z-score analysis  303830.0   0.0  1.0 -4.903 -0.533 -0.236  0.267  30.46

# %% [markdown]
# Mean of z-scores is 0 and standard deviation of z-scores is 1.0.<br>
# Minimum value is -4.903 and maximum value is 30.46

# %% [markdown]
# ### 4.2.1 Visualizing the z-scores tendencies

# %%
# Visualizing the results in histogram
bins = np.arange(-3,8,1)
plt.hist(h,bins)
plt.title("Histogram of Z-scores")
plt.xlabel("z-scores")
plt.savefig('images/zscore_histogram.png')
plt.show()

# %%
sb.distplot(h)
plt.title("Densithy plot of Z-scores")
plt.xlabel("z-scores")
plt.xlim(-3, 6)
plt.savefig('images/zscore_density.png')
plt.show()
# Out:
# /home/aditya/.local/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### 4.2.2 Attribute outlier analysis

# %%
# Setting z-score Threshold
threshold = 6

# Finding which attribute contributes to outlier the most.
z_new = abs(z)>threshold
z_count = z_new[z_new == True].count(axis=0)
pd.DataFrame(z_count.sort_values(ascending = False),columns = ["Number of Outliers"])
# Out:
#                                                     Number of Outliers
# Total Number of reported Still Births                               61
# Number of Vasectomies Conducted (Public + Pvt.)                     40
# Number of home deliveries attended by SBA train...                  37
# Total Number of MTPs ( Public) reported                             37
# Number having severe anaemia (Hb<7) treated at ...                  34
# Adverse Events Following Imunisation (Others)                       33
# Number of C-section deliveries conducted at pub...                  33
# Number of Major Operations                                          32
# Oral Pills distributed                                              29
# Number of Newborns having weight less than 2.5 kg                   29
# IUCD insertions done (pvt. facilities)                              28
# Number of Minor Operations                                          27
# Number of C-section deliveries conducted at pri...                  26
# Main workers Persons                                                25
# Literate Persons                                                    24
# Total Number of Abortions ( Spontaneous/ Induce...                  23
# Number having Hb level<11 (tested cases)                            21
# Total Number of Infant Deaths reported                              20
# Number of Pregnant women given 100 IFA tablets                      19
# Number of Home deliveries                                           17
# Number of home deliveries attended by Non SBA t...                  15
# IUCD Insertions done (public facilities)                            13
# Condom pieces distributed                                           11
# Number of Tubectomies Conducted (Public + Pvt.)                      9
# Total Sterilisation Conducted                                        9
# Institutional deliveries (Public Insts.+Pvt. In...                   9
# Population Persons                                                   9
# Number of Infants given OPV 0 (Birth Dose)                           9
# Number of pregnant women received 3 ANC check ups                    6
# Number of fully immunized children (9-11 months)                     5
# Non-workers Persons                                                  4
# TT2 or Booster given to Pregnant women (numbers)                     3
# Total number of pregnant women Registered for ANC                    3
# Number of New Borns Breast Fed within 1 hour                         2
# Number of Infants given DPT1                                         2
# Marginal workers Persons                                             2
# Number of Women Discharged under 48 hours of de...                   1
# Deliveries Conducted at Public Institutions                          1
# Sex Ratio at birth ( Female Live Bitrths/ Male ...                   1
# Number of Infants given BCG                                          1
# Number of Infants given DPT2                                         1
# Number of Infants given DPT3                                         1
# Total Number of reported live births                                 1
# Total reported deliveries                                            0
# Number of Infants given Measles                                      0
# Number of Pregnant women registered within firs...                   0

# %% [markdown]
# It shows that every column contains decent amount of outliers, but attribute 'Number of Vasectomies Conducted (Public + Pvt.) ' contains the most outliers.<br>
#
# ### 4.2.3 Boxplot on the attributes having highest and lowest number of outiler

# %%
data.boxplot(column = ["Number of Vasectomies Conducted (Public + Pvt.)","Sex Ratio at birth ( Female Live Bitrths/ Male Births *1000)","Total Number of reported Still Births","Adverse Events Following Imunisation (Others)"],figsize=(18,6))
# plt.tight_layout()
plt.savefig('images/boxplot.png')
plt.show()

# %%
df.boxplot("Population Persons")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 4.2.4 Total Number of Outliers

# %%
# Total number of outliers
z_count.sum()
# Out:
# 713

# %% [markdown]
# ## 4.3 Dropping Outliers

# %%
# Finding the rows containing the outliers
outlier_rows = np.where(abs(z)>threshold)
outlier_rows = list(set(outlier_rows[0]))
len(outlier_rows)
# Out:
# 424

# %% [markdown]
# So there are 583 rows which has outlier values. Removing these rows from the dataset. 12.7% of rows contains the outliers.

# %%
# Removing outliers from the data
data.drop(outlier_rows, axis = 0, inplace = True)
data.to_csv("dataset.csv", index = False)
data
# Out:
#       Total number of pregnant women Registered for ANC  \
# 0                                                2253.0
# 1                                                 925.0
# 2                                                1511.0
# 3                                                1043.0
# 4                                                1279.0
# ...                                                 ...
# 6591                                            28158.0
# 6592                                            28137.0
# 6595                                            36699.0
# 6596                                            52376.0
# 6602                                            58172.0
#
#       Number of Pregnant women registered within first trimester  \
# 0                                                 739.0
# 1                                                 247.0
# 2                                                 611.0
# 3                                                 278.0
# 4                                                 896.0
# ...                                                 ...
# 6591                                            23338.0
# 6592                                            20285.0
# 6595                                            32896.0
# 6596                                            44625.0
# 6602                                            53672.0
#
#       Number of pregnant women received 3 ANC check ups  \
# 0                                                2007.0
# 1                                                 638.0
# 2                                                1491.0
# 3                                                 554.0
# 4                                                1255.0
# ...                                                 ...
# 6591                                             2931.0
# 6592                                              839.0
# 6595                                             2427.0
# 6596                                             4532.0
# 6602                                            12079.0
#
#       TT2 or Booster given to Pregnant women (numbers)  \
# 0                                               1667.0
# 1                                                584.0
# 2                                               1097.0
# 3                                                485.0
# 4                                               1115.0
# ...                                                ...
# 6591                                              73.7
# 6592                                              70.7
# 6595                                              83.5
# 6596                                              79.8
# 6602                                              86.3
#
#       Number of Pregnant women given 100 IFA tablets  \
# 0                                             7857.0
# 1                                             1230.0
# 2                                             2674.0
# 3                                             1413.0
# 4                                             1397.0
# ...                                              ...
# 6591                                            80.5
# 6592                                            83.5
# 6595                                            89.4
# 6596                                            91.0
# 6602                                            86.3
#
#       Number having Hb level<11 (tested cases)  \
# 0                                       3496.0
# 1                                       4459.0
# 2                                       2715.0
# 3                                       3926.0
# 4                                       1509.0
# ...                                        ...
# 6591                                     115.0
# 6592                                     149.0
# 6595                                     462.0
# 6596                                     425.0
# 6602                                     386.0
#
#       Number having severe anaemia (Hb<7) treated at institution  \
# 0                                                  34.0
# 1                                                 214.0
# 2                                                 192.0
# 3                                                 335.0
# 4                                                  36.0
# ...                                                 ...
# 6591                                               71.9
# 6592                                               44.9
# 6595                                               45.1
# 6596                                               69.8
# 6602                                              138.4
#
#       Number of Home deliveries  \
# 0                         350.0
# 1                          39.0
# 2                         216.0
# 3                          62.0
# 4                         190.0
# ...                         ...
# 6591                        0.0
# 6592                        3.0
# 6595                        0.0
# 6596                        0.0
# 6602                        0.0
#
#       Number of home deliveries attended by SBA trained (Doctor/Nurse/ANM)  \
# 0                                                 123.0
# 1                                                  29.0
# 2                                                  89.0
# 3                                                  52.0
# 4                                                  76.0
# ...                                                 ...
# 6591                                              655.0
# 6592                                              299.0
# 6595                                              468.0
# 6596                                             3609.0
# 6602                                             2253.0
#
#       Number of home deliveries attended by Non SBA trained (trained TB/Dai)  \
# 0                                                 227.0
# 1                                                  10.0
# 2                                                 127.0
# 3                                                  10.0
# 4                                                 114.0
# ...                                                 ...
# 6591                                                0.0
# 6592                                                1.0
# 6595                                                0.0
# 6596                                                0.0
# 6602                                                0.0
#
#       ...  Adverse Events Following Imunisation (Others)  \
# 0     ...                                            0.0
# 1     ...                                            5.0
# 2     ...                                           11.0
# 3     ...                                           46.0
# 4     ...                                           45.0
# ...   ...                                            ...
# 6591  ...                                            0.0
# 6592  ...                                            0.0
# 6595  ...                                            0.0
# 6596  ...                                            0.0
# 6602  ...                                            0.0
#
#       Number of Major Operations  Number of Minor Operations  \
# 0                           29.0                        54.0
# 1                          106.0                       220.0
# 2                            0.0                        17.0
# 3                          116.0                       191.0
# 4                            0.0                        40.0
# ...                          ...                         ...
# 6591                     24067.0                        -6.0
# 6592                     26493.0                         9.8
# 6595                     33482.0                       -14.4
# 6596                     46237.0                        -0.5
# 6602                     51416.0                        -5.7
#
#       Total Number of Infant Deaths reported  Population Persons  \
# 0                                       22.0                   0
# 1                                       24.0               37333
# 2                                       15.0                   0
# 3                                       11.0               36842
# 4                                       15.0                   0
# ...                                      ...                 ...
# 6591                                     8.0             1789561
# 6592                                     4.0             2005944
# 6595                                    15.0             4186693
# 6596                                     9.0             3045026
# 6602                                     1.0             3195015
#
#       Literate Persons  Main workers Persons  Marginal workers Persons  \
# 0                    0                     0                         0
# 1                25449                  9936                      7392
# 2                    0                     0                         0
# 3                25331                  9650                      7473
# 4                    0                     0                         0
# ...                ...                   ...                       ...
# 6591           1300650                562706                    201525
# 6592           1543261                568138                    204888
# 6595           3032115               1238349                    419066
# 6596           2200010                976435                    261052
# 6602           1966489                594904                    751587
#
#       Non-workers Persons  Total Number of reported live births
# 0                       0                                1627.0
# 1                   19974                                 585.0
# 2                       0                                1095.0
# 3                   19717                                 484.0
# 4                       0                                 927.0
# ...                   ...                                   ...
# 6591              1026647                                 421.0
# 6592              1244036                                 551.0
# 6595              2532517                                 446.0
# 6596              1808281                                 793.0
# 6602              1867835                                 963.0
#
# [6181 rows x 46 columns]

# %% [markdown]
# ***
# ## 5. Feature Selection

# %%
# Filtering attributes of the data set.
attributes = [
# #                 "Indicator",
#                "Total number of pregnant women Registered for ANC",
#                "Number of Pregnant women registered within first trimester",
#                "Number of pregnant women received 3 ANC check ups",
#                "TT2 or Booster given to Pregnant women (numbers)",
#                "Number of Pregnant women given 100 IFA tablets",
#               # "Number having Hb level<11 (tested cases)",
#               # "Number having severe anaemia (Hb<7) treated at institution",
#                "Number of Home deliveries",
#                "Number of home deliveries attended by SBA trained (Doctor/Nurse/ANM)",
#               # "Number of home deliveries attended by Non SBA trained (trained TB/Dai)",
#                "Deliveries Conducted at Public Institutions",
#                "Number of Women Discharged under 48 hours of delivery in public facilities",
#                "Institutional deliveries (Public Insts.+Pvt. Insts.)",
#                "Total reported deliveries",
#               # "Number of C-section deliveries conducted at public facilities",
#               # "Number of C-section deliveries conducted at private facilities",
# #               "Total Number of reported live births",
# #               "Total Number of reported Still Births",
#                "Number of Newborns having weight less than 2.5 kg",
#                "Number of New Borns Breast Fed within 1 hour",
#                "Sex Ratio at birth ( Female Live Bitrths/ Male Births *1000)",
# #               "Total Number of Abortions ( Spontaneous/ Induced) Reported",
# #               "Total Number of MTPs ( Public) reported",
# #               "Number of Vasectomies Conducted (Public + Pvt.)",
# #               "Number of Tubectomies Conducted (Public + Pvt.)",
# #               "Total Sterilisation Conducted",
# #               "IUCD Insertions done (public facilities)",
# #               "IUCD insertions done (pvt. facilities)",
# #               "Oral Pills distributed",
# #               "Condom pieces distributed",
#                "Number of Infants given OPV 0 (Birth Dose)",
#                "Number of Infants given BCG",
#                "Number of Infants given DPT1",
#                "Number of Infants given DPT2",
#                "Number of Infants given DPT3",
#                "Number of Infants given Measles",
#                "Number of fully immunized children (9-11 months)",
#               "Adverse Events Following Imunisation (Others)",
#               # "Number of Major Operations",
#               # "Number of Minor Operations",
#               # "Total Number of Infant Deaths reported"
# #              "Population Persons",
# #              "Literate Persons",
# #              "Main workers Persons"
# #              "Marginal workers Persons",
# #              "Non-workers Persons"

              ]

# for i in attributes:
#     data.pop(i)

# %% [markdown]
# # 6. Prediction

# %% [markdown]
# ## 6.1 Case 1: Predicting number of Births

# %% [markdown]
# #### Independent and Dependent attributes for number of Live-Births

# %%
#dividing the data into dependent and independent variables
data = pd.read_csv('all_states_merged_8to18.csv')
data.drop("Indicator", axis = 1, inplace = True)
# data = pd.read_csv("dataset.csv")
x = data.drop(['Total Number of reported live births'], axis=1)
y = data['Total Number of reported live births']

# %% [markdown]
# #### Dividing the data into training and test set

# %%
# dividing data into test and train set
train_x,test_x,train_y,test_y = train_test_split(x,y,test_size=0.09,shuffle = False)

# %% [markdown]
# ## 6.1.1 Linear Regression Model

# %% [markdown]
# ### Learning the model

# %%
# Creating instance of Linear Regresssion
lr = LR()

# Fitting the model
lr.fit(train_x, train_y)

# Predicting over the Train Set 
train_predict = lr.predict(train_x)

# Predicting over the Test Set 
test_predict = lr.predict(test_x)

# %% [markdown]
# ### Evaluation of Results

# %%
# Mean Absolute Error
k = mae(train_predict, train_y)
print('Training Mean Absolute Error\t', k )
k = mae(test_predict, test_y)
print('Test Mean Absolute Error\t', k )

#Mean Square Error
print("Training Root Mean Square Error\t",np.sqrt(mse(train_predict, train_y)))
print("Testing Root Mean Square Error\t",np.sqrt(mse(test_predict, test_y)))
# Out:
# Training Mean Absolute Error	 2830.280200986205
# Test Mean Absolute Error	 5086.081679365477
# Training Root Mean Square Error	 5362.861539371022
# Testing Root Mean Square Error	 8382.417070614656

# %%
print('Training Accuracy(R-square)\t',r2_score(train_y, train_predict)*100)
print('Testing Accuracy(R-square)\t',r2_score(test_y, test_predict)*100)
# Out:
# Training Accuracy(R-square)	 95.7267133469734
# Testing Accuracy(R-square)	 93.3956749351076

# %%
# Coefficients and Intercept of the learned model (that is the weight vector w)
np.set_printoptions(suppress=True)
coeff = (lr.coef_)
print("Coefficient Values: ",coeff)
print("Intercept value: ",lr.intercept_)
# Out:
# Coefficient Values:  [ 0.0365245  -0.02414828  0.13131665  0.0092935  -0.00843497 -0.03303275
#  -0.1672311   0.29762993  0.09473943  0.45669489 -0.07976531  0.03509029
#   0.50488948  0.01454787  0.0187765   0.22133006 -0.45679793  0.13462615
#   0.17768227 11.16181058  0.16270571  0.04182976 -1.22451431 -1.40042178
#   1.39851048  0.08814134 -0.0876141   0.00700272 -0.00006108  0.14240465
#   0.00361172 -0.03237768  0.2186664  -0.15190821 -0.01356492  0.03551135
#  -0.22385058 -0.01614913 -0.00972167  0.97889908  0.01097152  0.00056534
#  -0.01195543 -0.0110972  -0.01118158]
# Intercept value:  -10380.213685471634

# %%
# Coefficient Plot
plt.figure(figsize=(5, 3.5), dpi=100, facecolor='w', edgecolor='b')
x = range(len(train_x.columns))
y = lr.coef_
plt.bar( x, y )
plt.xlabel( "Variables")
plt.ylabel('Coefficients')
plt.title('Normalized Coefficient plot')
plt.savefig("images/coefficient_plot.jpg")
plt.show()

# %% [markdown]
# Coefficient plot tells us that our target variable highly depends on 1 attribute and it is positve correlated. Coefficient values of 40 attributes is very less, this shows that only 5 attributes majorly contribute to our prediction.

# %% [markdown]
# #### Identifying Feature Importance

# %%
# Identifying the attributes which influenced the model most.
coeff = pd.DataFrame(lr.coef_,columns= ["coefficent"])
coeff.sort_values(by = "coefficent", ascending = False)
coeff[abs(coeff.coefficent)>0.9].index
column_names = train_x.columns
pd.DataFrame(column_names[coeff[abs(coeff.coefficent)>0.9].index], columns = ["Most Influencial Attributes"])
# Out:
#                          Most Influencial Attributes
# 0  Sex Ratio at birth ( Female Live Bitrths/ Male...
# 1    Number of Vasectomies Conducted (Public + Pvt.)
# 2    Number of Tubectomies Conducted (Public + Pvt.)
# 3                      Total Sterilisation Conducted
# 4             Total Number of Infant Deaths reported

# %% [markdown]
# Target attribute is positively correlated with the attributes - Sex Ratio at birth, Total Sterilisation Conducted, Total Number of Infant Deaths reported and is negatively correlated with attributes - Number of Vasectomies Conducted and Number of Tubectomies Conducted. This makes sense too as Vasectomies and Tubectomies makes humans infertile and hence will reduce the number of child births.

# %%
# Arranging and calculating the Residuals
residuals = pd.DataFrame({
    'fitted values' : test_y,
    'predicted values' : test_predict,
})

residuals['residuals'] = residuals['fitted values'] - residuals['predicted values']
residuals.head()
# print(len(residuals))
# Out:
#       fitted values  predicted values     residuals
# 6010        76955.0      65200.341004  11754.658996
# 6011        41504.0      46525.360539  -5021.360539
# 6012        66869.0      67874.782892  -1005.782892
# 6013        46524.0      45866.495414    657.504586
# 6014        38063.0      35226.134390   2836.865610

# %% [markdown]
# ### Residual Plot

# %%
plt.figure(figsize=(4, 4), dpi=120, facecolor='w', edgecolor='b')
f = range(0,len(residuals))
k = [0 for i in range(0,len(residuals))]
plt.scatter( f, residuals.residuals[:], label = 'residuals')
plt.plot( f, k , color = 'red', label = 'regression line' )
plt.xlabel('fitted points ')
plt.ylabel('residuals')
plt.title('Residual plot')
plt.ylim(-2000,2000)
plt.legend()
plt.savefig("images/residual-plot.jpg")
plt.show()

# %%
# Histogram for distribution
plt.figure(figsize=(4, 4), dpi=120, facecolor='w', edgecolor='b')
plt.hist(residuals.residuals, bins = 50)
plt.xlabel('Error')
plt.ylabel('Frequency')
plt.title('Distribution of Error Terms')
plt.savefig("images/residual-histogram.jpg")
plt.show()

# %%
 # Plotting the QQ plot
from statsmodels.graphics.gofplots import qqplot

fig, ax = plt.subplots()
qqplot(residuals.residuals, line = 's' , ax = ax)
plt.ylabel('Residual Quantiles')
plt.xlabel('Ideal Scaled Quantiles')
plt.title('Checking distribution of Residual Errors')
plt.savefig("images/residual-qqplot.jpg")
plt.show()

# %% [markdown]
# ## 6.1.2 Random Forest

# %% [markdown]
# Random forest accuracy without outlier data is 98% and with outlier data is 96%

# %% [markdown]
# #### Independent and Dependent attributes for number of Live-Births

# %%
#dividing the data into dependent and independent variables
data = pd.read_csv('all_states_merged_8to18.csv')
data.drop("Indicator", axis = 1, inplace = True)

# Dropping attributes which will be not available for predicting in practical scenario
x = data.drop(['Total Number of reported live births','Total reported deliveries','Institutional deliveries (Public Insts.+Pvt. Insts.)',
       'Number of New Borns Breast Fed within 1 hour',
       'Sex Ratio at birth ( Female Live Bitrths/ Male Births *1000)','Number of Newborns having weight less than 2.5 kg','Total Number of reported Still Births','Number of C-section deliveries conducted at private facilities',
       'Number of Home deliveries'], axis=1)
y = data['Total Number of reported live births']

# %% [markdown]
# #### Dividing the data into training and test set

# %%
# dividing data into test and train set
train_x,test_x,train_y,test_y = train_test_split(x,y,test_size=0.09,shuffle = False)

# %% [markdown]
# #### Learning the model

# %%
# create Births regressor object of Random Forest
regressor = RandomForestRegressor(n_estimators = 25,random_state = 0)

# fit the regressor with x and y data
regressor.fit(train_x, train_y)

# predicting for train and test set
train_predict = regressor.predict(train_x)
test_predict = regressor.predict(test_x)

# %%
test_yLIST = list(test_y)
# for i in range(len(test_yLIST)):
#     print(test_yLIST[i],"<--->",y_pred[i])

# %%
 print(max(abs(test_yLIST - test_predict)))
print(len(test_yLIST))
# Out:
# 66776.04000000001
# 595

# %% [markdown]
# #### Evaluating Results

# %%
# Mean Absolute Error
k = mae(train_predict, train_y)
print('Training Mean Absolute Error\t', k )
k = mae(test_predict, test_y)
print('Test Mean Absolute Error\t', k )

#Mean Square Error
print("Training Root Mean Square Error\t",np.sqrt(mse(train_predict, train_y)))
print("Testing Root Mean Square Error\t",np.sqrt(mse(test_predict, test_y)))
# Out:
# Training Mean Absolute Error	 1057.194615640599
# Test Mean Absolute Error	 3401.966789915966
# Training Root Mean Square Error	 2093.3239558461883
# Testing Root Mean Square Error	 6447.811690937131

# %%
# R square values for training and test predicted values
print('Training Accuracy(R-square)\t',r2_score(train_y, train_predict)*100)
print('Testing Accuracy(R-square)\t',r2_score(test_y, test_predict)*100)
# Out:
# Training Accuracy(R-square)	 99.34890892113205
# Testing Accuracy(R-square)	 96.09235951233931

# %% [markdown]
# #### Plot

# %%
# Plotting Actual vs Predicted
test_yLIST = list(test_y)
impactData = []
impactData.append(test_yLIST)
impactData.append(list(test_predict))
plt.figure(figsize = (13,6))
for i in range(0,2):
    test_pred = plt.plot(impactData[i])
    test_pred = plt.xlabel('Districts')
    # test_pred = plt.ylabel('Deaths')
    test_pred = plt.ylabel('Births')
plt.legend(['Actual','Predicted'])
plt.savefig('images/RandomForestLiveBirth.jpg')
plt.show()

# %% [markdown]
# #### Identifying Importance of the Features

# %%
# Identifying features that has most importance
print(regressor.feature_importances_)
# Out:
# [0.09161601 0.0018511  0.20930097 0.00450111 0.001493   0.00094048
#  0.00132975 0.00256929 0.00298724 0.00673665 0.00173479 0.00189465
#  0.00212681 0.00168227 0.00140742 0.00261603 0.00267634 0.00144542
#  0.00096754 0.0015915  0.00211097 0.04504081 0.19215329 0.0028407
#  0.00208439 0.00272512 0.0031545  0.39348276 0.00098459 0.00124535
#  0.00094276 0.00164663 0.00269164 0.00162666 0.00216645 0.0015616
#  0.0020734 ]

# %%
# Printing the name of the features those has most importance for Random Forest model.
values1 = regressor.feature_importances_
values2 = train_x.columns
listValues = []
for i in range(len(values1)):
    tmp = []
    tmp.append(values1[i])
    tmp.append(values2[i])
    listValues.append(tmp)

listValues.sort(key = lambda x:x[0],reverse = True)
for i in range(10):
    print(listValues[i][1])
# Out:
# Number of fully immunized children (9-11 months)
# Number of pregnant women received 3 ANC check ups
# Number of Infants given BCG
# Total number of pregnant women Registered for ANC
# Number of Infants given OPV 0 (Birth Dose)
# Deliveries Conducted at Public Institutions
# TT2 or Booster given to Pregnant women (numbers)
# Number of Infants given Measles
# Number of home deliveries attended by Non SBA trained (trained TB/Dai)
# Number of Infants given DPT1

# %% [markdown]
# ## 6.2 Case 2: Predicting number of Still-Births

# %% [markdown]
# Linear regression gives accuracy of 92% whereas Random Forest gives accuracy of 98%

# %% [markdown]
# #### Independent and Dependent attributes for number of Still-Births

# %%
data = pd.read_csv('all_states_merged_8to18.csv')
data.drop("Indicator", axis = 1, inplace = True)

# %%
x_still = data.drop(['Total Number of reported Still Births'], axis=1)
y_still = data['Total Number of reported Still Births']

# %%
# dividing data into test and train set
train_x,test_x,train_y,test_y = train_test_split(x_still,y_still,test_size=0.1,shuffle=False)

# %% [markdown]
# ### 6.2.1 Linear Regression Model

# %% [markdown]
# #### Learning the model

# %%
# Creating instance of Linear Regresssion
lr = LR()

# Fitting the model
lr.fit(train_x, train_y)

# Predicting over the Train Set 
train_predict = lr.predict(train_x)

# Predicting over the Test Set 
test_predict = lr.predict(test_x)

# %% [markdown]
# #### Results

# %%
# Mean Absolute Error
k = mae(train_predict, train_y)
print('Training Mean Absolute Error\t', k )
k = mae(test_predict, test_y)
print('Test Mean Absolute Error\t', k )

#Mean Square Error
print("Training Root Mean Square Error\t",np.sqrt(mse(train_predict, train_y)))
print("Testing Root Mean Square Error\t",np.sqrt(mse(test_predict, test_y)))
# Out:
# Training Mean Absolute Error	 1023.9926194934404
# Test Mean Absolute Error	 2390.0415296631895
# Training Root Mean Square Error	 2235.3124754075225
# Testing Root Mean Square Error	 4821.804893521151

# %%
# R square values for training and test predicted values
print('Training Accuracy(R-square)\t',r2_score(train_y, train_predict)*100)
print('Testing Accuracy(R-square)\t',r2_score(test_y, test_predict)*100)
# Out:
# Training Accuracy(R-square)	 88.12439580106799
# Testing Accuracy(R-square)	 92.45550999545367

# %% [markdown]
# #### Plot Actual vs Predicted

# %%
# Plotting Actual vs Predicted
test_yLIST = list(test_y)
impactData = []
impactData.append(test_yLIST)
impactData.append(list(test_predict))
plt.figure(figsize = (13,6))
for i in range(0,2):
    test_pred = plt.plot(impactData[i])
    test_pred = plt.xlabel('Districts')
    test_pred = plt.ylabel('Still-Births')
plt.legend(['Actual','Predicted'])
plt.savefig('images/RandomForestStillBirth.jpg')
plt.show()

# %% [markdown]
# #### Identifying Feature Importance

# %%
# Identifying the attributes which influenced the model most.
coeff = pd.DataFrame(lr.coef_,columns= ["coefficent"])
coeff.sort_values(by = "coefficent", ascending = False)
coeff[abs(coeff.coefficent)>0.9].index
column_names = train_x.columns
pd.DataFrame(column_names[coeff[abs(coeff.coefficent)>0.9].index], columns = ["Most Influencial Attributes"])
# Out:
#                          Most Influencial Attributes
# 0                          Number of Home deliveries
# 1  Number of home deliveries attended by SBA trai...
# 2  Number of home deliveries attended by Non SBA ...
# 3  Institutional deliveries (Public Insts.+Pvt. I...
# 4                          Total reported deliveries
# 5  Sex Ratio at birth ( Female Live Bitrths/ Male...
# 6    Number of Vasectomies Conducted (Public + Pvt.)
# 7    Number of Tubectomies Conducted (Public + Pvt.)
# 8                      Total Sterilisation Conducted

# %% [markdown]
# ### 6.2.2 Random Forest

# %%
# create regressor object of Random Forest
regressor = RandomForestRegressor(n_estimators = 25,random_state = 0)

# fit the regressor with x and y data
regressor.fit(train_x, train_y)

y_pred = regressor.predict(test_x)

# %% [markdown]
# #### Evaluating Results

# %%
# Mean Absolute Error
k = mae(train_predict, train_y)
print('Training Mean Absolute Error\t', k )
k = mae(test_predict, test_y)
print('Test Mean Absolute Error\t', k )

#Mean Square Error
print("Training Root Mean Square Error\t",np.sqrt(mse(train_predict, train_y)))
print("Testing Root Mean Square Error\t",np.sqrt(mse(test_predict, test_y)))
# Out:
# Training Mean Absolute Error	 1023.9926194934404
# Test Mean Absolute Error	 2390.0415296631895
# Training Root Mean Square Error	 2235.3124754075225
# Testing Root Mean Square Error	 4821.804893521151

# %%
print('Training Accuracy : ',regressor.score(train_x,train_y)*100)
print('Testing Accuracy : ',regressor.score(test_x,test_y)*100)
# Out:
# Training Accuracy :  99.62728718459579
# Testing Accuracy :  98.51452557349563

# %% [markdown]
# #### Identifying Importance of the Features

# %%
# Identifying features that has most importance
print(regressor.feature_importances_)
# Out:
# [0.00259806 0.00124975 0.00025699 0.03050491 0.00038897 0.00052046
#  0.00011194 0.00072458 0.00069687 0.00047195 0.00107304 0.0001137
#  0.00987095 0.07348751 0.00019359 0.00016737 0.16293468 0.0002345
#  0.0005019  0.00046917 0.00062046 0.00020278 0.00014589 0.00082377
#  0.00086076 0.00009624 0.00013515 0.02958391 0.00088289 0.6693513
#  0.00021338 0.00076391 0.00021609 0.00073538 0.00083083 0.00015996
#  0.00102746 0.00113056 0.00046368 0.00047891 0.00031905 0.0007016
#  0.00030407 0.00033205 0.00304904]

# %%
# Printing the name of the features those has most importance for Random Forest model.
values1 = regressor.feature_importances_
values2 = train_x.columns
listValues = []
for i in range(len(values1)):
    tmp = []
    tmp.append(values1[i])
    tmp.append(values2[i])
    listValues.append(tmp)

listValues.sort(key = lambda x:x[0],reverse = True)
for i in range(10):
    print(listValues[i][1])
# Out:
# Number of Infants given BCG
# Number of Newborns having weight less than 2.5 kg
# Total reported deliveries
# TT2 or Booster given to Pregnant women (numbers)
# Condom pieces distributed
# Institutional deliveries (Public Insts.+Pvt. Insts.)
# Total Number of reported live births
# Total number of pregnant women Registered for ANC
# Number of Pregnant women registered within first trimester
# Number of Minor Operations

# %% [markdown]
# ## 6.3 Case 3: Predicting number of Infant-Deaths

# %% [markdown]
# 49% accuracy with linear regression and 69% accuracy with Random Forest.

# %%
data = pd.read_csv('all_states_merged_8to18.csv')
data.drop("Indicator", axis = 1, inplace = True)

# %%
x_death = data.drop(['Total Number of Infant Deaths reported'], axis=1)
y_death = data['Total Number of Infant Deaths reported']

# %%
# dividing data into test and train set
# train_x,test_x,train_y,test_y = train_test_split(x_death,y_death,test_size=0.09,shuffle=False)
train_x,test_x,train_y,test_y = train_test_split(x_death,y_death,test_size=0.09,random_state = 44)

# %% [markdown]
# ### 6.3.1 Linear Regression

# %% [markdown]
# #### Learning the model

# %%
# Creating instance of Linear Regresssion
lr = LR()

# Fitting the model
lr.fit(train_x, train_y)

# Predicting over the Train Set and calculating error
train_predict = lr.predict(train_x)

# Predicting over the Test Set and calculating error
test_predict = lr.predict(test_x)

# %% [markdown]
# #### Results

# %%
# Mean Absolute Error
k = mae(train_predict, train_y)
print('Training Mean Absolute Error\t', k )
k = mae(test_predict, test_y)
print('Test Mean Absolute Error\t', k )

#Mean Square Error
print("Training Root Mean Square Error\t",np.sqrt(mse(train_predict, train_y)))
print("Testing Root Mean Square Error\t",np.sqrt(mse(test_predict, test_y)))
# Out:
# Training Mean Absolute Error	 176.98444922111506
# Test Mean Absolute Error	 171.44992601028855
# Training Root Mean Square Error	 284.300609512833
# Testing Root Mean Square Error	 265.06288848278155

# %%
# R square values for training and test predicted values
print('Training Accuracy(R-square)\t',r2_score(train_y, train_predict)*100)
print('Testing Accuracy(R-square)\t',r2_score(test_y, test_predict)*100)
# Out:
# Training Accuracy(R-square)	 48.09697806858291
# Testing Accuracy(R-square)	 49.51743097935387

# %% [markdown]
# #### Plot Actual vs Predicted

# %%
# Plotting Actual vs Predicted
test_yLIST = list(test_y)
impactData = []
impactData.append(test_yLIST)
impactData.append(list(test_predict))
plt.figure(figsize = (13,6))
for i in range(0,2):
    test_pred = plt.plot(impactData[i])
    test_pred = plt.xlabel('Districts')
    test_pred = plt.ylabel('Infant-Deaths')
plt.legend(['Actual','Predicted'])
plt.savefig('images/RandomForestInfantDeaths.jpg')
plt.show()

# %%
# Coefficients and Intercept of the learned model (that is the weight vector w)
coeff = (lr.coef_)
print("Coefficient Values: ",coeff)
print("Intercept value: ",lr.intercept_)
# Out:
# Coefficient Values:  [ 0.00107771 -0.00088671 -0.00198221 -0.00258871 -0.00039057  0.0006334
#   0.00327435 -0.01103944 -0.02124058 -0.00500898 -0.00258202 -0.00498556
#  -0.01970527  0.02799373  0.0246406  -0.0215682  -0.00826752  0.00434802
#  -0.00102659  0.00712953  0.01448815 -0.00337943 -0.04032797 -0.11177873
#   0.11837507 -0.00084827 -0.0225917   0.00064728  0.00000688  0.00472069
#   0.00088473  0.00188911 -0.00642843  0.00447119 -0.00114928 -0.00135388
#   0.04061433 -0.00029628  0.00016219  0.00239437 -0.00001812 -0.00217876
#  -0.00199174 -0.00258792  0.00266929]
# Intercept value:  20.742183234181795

# %%
# Coefficient Plot
plt.figure(figsize=(5, 3.5), dpi=100, facecolor='w', edgecolor='b')
x = range(len(train_x.columns))
y = lr.coef_
plt.bar( x, y )
plt.xlabel( "Variables")
plt.ylabel('Coefficients')
plt.title('Normalized Coefficient plot')
plt.savefig("images/death-coefficient_plot.jpg")
plt.show()

# %% [markdown]
# #### Identifying Feature Importance

# %%
# Identifying the attributes which influenced the model most.
coeff = pd.DataFrame(lr.coef_,columns= ["coefficent"])
coeff.sort_values(by = "coefficent", ascending = False)
coeff[abs(coeff.coefficent)>0.02].index
column_names = train_x.columns
pd.DataFrame(column_names[coeff[abs(coeff.coefficent)>0.02].index], columns = ["Most Influencial Attributes"])
# Out:
#                          Most Influencial Attributes
# 0  Number of home deliveries attended by SBA trai...
# 1                          Total reported deliveries
# 2  Number of C-section deliveries conducted at pu...
# 3  Number of C-section deliveries conducted at pr...
# 4    Number of Vasectomies Conducted (Public + Pvt.)
# 5    Number of Tubectomies Conducted (Public + Pvt.)
# 6                      Total Sterilisation Conducted
# 7             IUCD insertions done (pvt. facilities)
# 8      Adverse Events Following Imunisation (Others)

# %% [markdown]
# ### Residual Plot

# %%
# Arranging and calculating the Residuals
residuals = pd.DataFrame({
    'fitted values' : test_y,
    'predicted values' : test_predict,
})

residuals['residuals'] = residuals['fitted values'] - residuals['predicted values']
residuals.head()
# print(len(residuals))
# Out:
#       fitted values  predicted values   residuals
# 6224            0.0        327.875307 -327.875307
# 4314            7.0        138.360740 -131.360740
# 2369           33.0        137.981291 -104.981291
# 5062           92.0        235.868400 -143.868400
# 2540          829.0        495.358003  333.641997

# %%
plt.figure(figsize=(4, 4), dpi=80, facecolor='w', edgecolor='b')
f = range(0,len(residuals))
k = [0 for i in range(0,len(residuals))]
plt.scatter( f, residuals.residuals[:], label = 'residuals')
plt.plot( f, k , color = 'red', label = 'regression line' )
plt.xlabel('fitted points ')
plt.ylabel('residuals')
plt.title('Residual plot')
plt.ylim(-2000,2000)
plt.legend()
plt.savefig("images/death-residual-plot.jpg")
plt.show()

# %% [markdown]
# Since variance of residuals remains constant with response variable magnitude we can conclude that data-set respects homoscedasticity. But residuals are not distributed uniformly, they’re pretty symmetrically distributed, tending to cluster towards the middle of the plot.

# %%
# Histogram for distribution
plt.figure(figsize=(4, 4), dpi=120, facecolor='w', edgecolor='b')
plt.hist(residuals.residuals, bins = 50)
plt.xlabel('Error')
plt.ylabel('Frequency')
plt.title('Distribution of Error Terms')
plt.savefig("images/death-residual-histogram.jpg")
plt.show()

# %%
 # Plotting the QQ plot
from statsmodels.graphics.gofplots import qqplot

fig, ax = plt.subplots()
qqplot(residuals.residuals, line = 's' , ax = ax)
plt.ylabel('Residual Quantiles')
plt.xlabel('Ideal Scaled Quantiles')
plt.title('Checking distribution of Residual Errors')
plt.savefig("images/death-residual-qqplot.jpg")
plt.show()

# %% [markdown]
# From Histogram and QQ-Plot of residuals we can say that data-set is normal for target variable - infant deaths.

# %% [markdown]
# Since data stasifies conditions of normality, Homoscedasticity, Linear relationship. Last thing left is check for Multicollinearity. Variance Inflation Factor test is best suited for it. If VIFk = 1, variable k is not correlated with any other independent variable. As a rule of thumb, multicollinearity is a potential problem when VIFk is greater than 4; and, a serious problem when it is greater than 10.

# %% [markdown]
# ## Variance Inflation Factor Test

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor 
vif_data = pd.DataFrame() 
vif_data["feature"] = train_x.columns 
  
# calculating VIF for each feature 
vif_data["VIF"] = [variance_inflation_factor(data.values, i) 
                          for i in range(len(train_x.columns))] 
  
vif_data = vif_data.sort_values(by = "VIF",ascending=False).reset_index(drop = True)
vif_data
# Out:
#                                               feature           VIF
# 0                                    Literate Persons  92467.995672
# 1                Total Number of reported live births  35924.277775
# 2                           Total reported deliveries  31186.143543
# 3   Institutional deliveries (Public Insts.+Pvt. I...  21204.626695
# 4                            Marginal workers Persons   8631.852523
# 5                       Total Sterilisation Conducted   8035.113268
# 6     Number of Tubectomies Conducted (Public + Pvt.)   7671.763229
# 7                                 Non-workers Persons    986.105534
# 8   Number of home deliveries attended by Non SBA ...    828.966345
# 9   Number of home deliveries attended by SBA trai...    800.939126
# 10                       Number of Infants given DPT2    393.108369
# 11                       Number of Infants given DPT3    236.767165
# 12                          Number of Home deliveries    195.271135
# 13                       Number of Infants given DPT1    153.434271
# 14                               Main workers Persons    107.136348
# 15                        Number of Infants given BCG     57.573416
# 16                    Number of Infants given Measles     51.076832
# 17  Total number of pregnant women Registered for ANC     34.473289
# 18  Number of pregnant women received 3 ANC check ups     31.956168
# 19   TT2 or Booster given to Pregnant women (numbers)     29.394356
# 20    Number of Vasectomies Conducted (Public + Pvt.)     23.762352
# 21        Deliveries Conducted at Public Institutions     20.375933
# 22         Number of Infants given OPV 0 (Birth Dose)     20.028542
# 23   Number of fully immunized children (9-11 months)     13.840468
# 24       Number of New Borns Breast Fed within 1 hour     13.000577
# 25  Number of Pregnant women registered within fir...     12.573843
# 26              Total Number of reported Still Births     10.430285
# 27           IUCD Insertions done (public facilities)      5.935899
# 28  Number of Women Discharged under 48 hours of d...      5.747381
# 29  Number of Newborns having weight less than 2.5 kg      5.222202
# 30           Number having Hb level<11 (tested cases)      4.888577
# 31                          Condom pieces distributed      4.373762
# 32                             Oral Pills distributed      3.886984
# 33  Sex Ratio at birth ( Female Live Bitrths/ Male...      3.369403
# 34     Number of Pregnant women given 100 IFA tablets      3.042396
# 35  Number of C-section deliveries conducted at pu...      3.024219
# 36  Number of C-section deliveries conducted at pr...      3.011501
# 37                         Number of Major Operations      2.981212
# 38                                 Population Persons      2.639889
# 39            Total Number of MTPs ( Public) reported      2.514823
# 40  Total Number of Abortions ( Spontaneous/ Induc...      2.338375
# 41                         Number of Minor Operations      2.022216
# 42  Number having severe anaemia (Hb<7) treated at...      1.737876
# 43             IUCD insertions done (pvt. facilities)      1.717663
# 44      Adverse Events Following Imunisation (Others)      1.166289

# %% [markdown]
# Since 27 out of 46 attributes have VIF greater than 10, it shows that our data suffers from heavy multicollinearity.

# %%
# Dropping the attributes having VIF>10 and again training the Model 
drop_attributes = list(vif_data[:27].feature)
data1 = data.drop(drop_attributes,axis =1)
x_death = data1.drop(['Total Number of Infant Deaths reported'], axis=1)
y_death = data1['Total Number of Infant Deaths reported']
train_x,test_x,train_y,test_y = train_test_split(x_death,y_death,test_size=0.09,random_state = 44)
# Creating instance of Linear Regresssion
lr = LR()

# Fitting the model
lr.fit(train_x, train_y)

# Predicting over the Train Set and calculating error
train_predict = lr.predict(train_x)

k = mae(train_predict, train_y)
print('Training Mean Absolute Error', k )

# Predicting over the Test Set and calculating error
test_predict = lr.predict(test_x)
k = mae(test_predict, test_y)
print('Test Mean Absolute Error    ', k )

print('Testing Accuracy : ',r2_score(test_y, test_predict)*100)
# Out:
# Training Mean Absolute Error 198.47459200396483
# Test Mean Absolute Error     188.71690769453153
# Testing Accuracy :  36.952329885748625

# %% [markdown]
# Accuracy of the linear regression dropped on dropping the attributes so calculating the VIF for the remaining attributes.

# %%
vif_data = pd.DataFrame() 
vif_data["feature"] = train_x.columns 
  
# calculating VIF for each feature 
vif_data["VIF"] = [variance_inflation_factor(data.values, i) 
                          for i in range(len(train_x.columns))] 
  
vif_data = vif_data.sort_values(by = "VIF",ascending=False).reset_index(drop = True)
vif_data[vif_data.VIF>10]
# Out:
#                                               feature           VIF
# 0                           Condom pieces distributed  31186.143543
# 1                              Oral Pills distributed  21204.626695
# 2             Total Number of MTPs ( Public) reported    828.966345
# 3   Total Number of Abortions ( Spontaneous/ Induc...    800.939126
# 4   Sex Ratio at birth ( Female Live Bitrths/ Male...    195.271135
# 5      Number of Pregnant women given 100 IFA tablets     34.473289
# 6   Number having severe anaemia (Hb<7) treated at...     31.956168
# 7   Number of Women Discharged under 48 hours of d...     29.394356
# 8            IUCD Insertions done (public facilities)     20.375933
# 9            Number having Hb level<11 (tested cases)     12.573843
# 10                         Number of Minor Operations     10.430285

# %% [markdown]
# Since 11 attributes out of 19 attributes are having VIF values greater than 10 in the remaining data-set. We can conclude that attributes of data-set is highly correlated with each other and accuracy of Regression models will always suffer. Let us apply Random Forest Model on this problem statement.

# %% [markdown]
# ### 6.3.2 Random Forest

# %%
data = pd.read_csv('all_states_merged_8to18.csv')
data.drop("Indicator", axis = 1, inplace = True)

# %%
x_death = data.drop(['Total Number of Infant Deaths reported'], axis=1)
y_death = data['Total Number of Infant Deaths reported']

# %%
# dividing data into test and train set
# train_x,test_x,train_y,test_y = train_test_split(x_death,y_death,test_size=0.09,shuffle=False)
train_x,test_x,train_y,test_y = train_test_split(x_death,y_death,test_size=0.1,random_state = 44)

# %%
# create regressor object of Random Forest
regressor = RandomForestRegressor(n_estimators = 25,random_state = 0)

# fit the regressor with x and y data
regressor.fit(train_x, train_y)

train_predict = regressor.predict(train_x)
test_predict = regressor.predict(test_x)

# %% [markdown]
# #### Results

# %%
# Mean Absolute Error
k = mae(train_predict, train_y)
print('Training Mean Absolute Error\t', k )
k = mae(test_predict, test_y)
print('Test Mean Absolute Error\t', k )

#Mean Square Error
print("Training Root Mean Square Error\t",np.sqrt(mse(train_predict, train_y)))
print("Testing Root Mean Square Error\t",np.sqrt(mse(test_predict, test_y)))
# Out:
# Training Mean Absolute Error	 44.47679676985195
# Test Mean Absolute Error	 113.2001815431165
# Training Root Mean Square Error	 87.23965230976026
# Testing Root Mean Square Error	 201.14927401387413

# %%
# R square values for training and test predicted values
print('Training Accuracy(R-square)\t',r2_score(train_y, train_predict)*100)
print('Testing Accuracy(R-square)\t',r2_score(test_y, test_predict)*100)
# Out:
# Training Accuracy(R-square)	 95.12455070018713
# Testing Accuracy(R-square)	 70.56988968985102

# %% [markdown]
# #### Plot Actual vs Predicted

# %%
# Plotting Actual vs Predicted
test_yLIST = list(test_y)
impactData = []
impactData.append(test_yLIST)
impactData.append(list(test_predict))
plt.figure(figsize = (13,6))
for i in range(0,2):
    test_pred = plt.plot(impactData[i])
    test_pred = plt.xlabel('Districts')
    test_pred = plt.ylabel('Infant-Deaths')
plt.legend(['Actual','Predicted'])
plt.savefig('images/RandomForestInfantDeathrandom.jpg')
plt.show()

# %% [markdown]
# #### Identifying Importance of the Features

# %%
# Identifying features that has most importance
print(regressor.feature_importances_)
# Out:
# [0.00505949 0.00637348 0.00624748 0.016551   0.00809243 0.01135031
#  0.01237999 0.0092006  0.01927328 0.02220971 0.01901915 0.01258248
#  0.02004781 0.006945   0.07115528 0.01581008 0.14273631 0.02109852
#  0.00781575 0.0119182  0.09905306 0.00952123 0.01517311 0.01916265
#  0.09826341 0.02148784 0.01551827 0.02925741 0.0073197  0.00703065
#  0.0083715  0.00569789 0.00998447 0.006632   0.01109858 0.00688545
#  0.01516881 0.02457208 0.01195628 0.00496665 0.0074727  0.01467291
#  0.02147348 0.00843192 0.0749616 ]

# %%
# Printing the name of the features those has most importance for Random Forest model.
values1 = regressor.feature_importances_
values2 = train_x.columns
listValues = []
for i in range(len(values1)):
    tmp = []
    tmp.append(values1[i])
    tmp.append(values2[i])
    listValues.append(tmp)

listValues.sort(key = lambda x:x[0],reverse = True)
for i in range(10):
    print(listValues[i][1])
# Out:
# Total Number of reported Still Births
# Total Number of Abortions ( Spontaneous/ Induced) Reported
# Total Sterilisation Conducted
# Total Number of reported live births
# Number of C-section deliveries conducted at public facilities
# Oral Pills distributed
# Number of Major Operations
# Number of home deliveries attended by Non SBA trained (trained TB/Dai)
# IUCD Insertions done (public facilities)
# Marginal workers Persons
